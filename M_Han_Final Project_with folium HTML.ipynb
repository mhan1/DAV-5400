# %% [markdown]
# # Final Project

# %% [markdown]
# ## Introduction
#  In the state of New York, New York City which comprises five boroughs such as Manhattan, Queens, Brooklyn, Bronx and Staten Island, is the largest city in the United States. The estimated population for New York City is 8.6 million in 2017, and it is expected to reach 9 million by 2040. In order to serve this huge population, the number of open restaurants in New York City should be high enough, as we can easily imagine. As of December 31 of 2017, there are 26.7K open restaurants in New York City. This plethora of eateries offered in New York City can overwhelm New Yorkers when they need to decide where to go and what to eat. In addition, the average American eats about 4.2 commercially prepared meals per week as of 2017, in other words, as a nation, Americans eat out between four and five times a week on average which is equivalent to 18.2 meals in a month.
#
#  Considering all of these, I was motivated to analyze the open restaurants in New York City, to provide New Yorkers with valuable insights regarding where to eat based on sound grounding. Despite the fact that there are a lot of reviews of restaurants available at our finger tip, it is hard to know if the restaurants of interest comply with the City and State food safety regulations through most of those reviews by customers that many people rely on when they eat outside the home. Hence, I expect my research questions in this project to help New Yorkers and visitors make better decisions when they consider eating out in New York City.

# %% [markdown]
# ## Research Questions
#
# I want to divide my research questions by two different perspectives for better clarity.
# One is for recommended restaurants, and another is for restaurants to avoid.
#
# For recommended restaurants,
# <br>
# 1) What are the restaurants that are compliant with the City and State food safety regulations in NYC?
# <br>
# 2) Are those restaurants getting better over time and/or keep hygiene constantly?
# <br>
# 3) What does Yelp say about the best restaurant in terms of star rating and reviews?
#
# For restaurants to avoid,
# <br>
# 1) What are the restaurants that are not compliant with the City and State food safety regulations in NYC?
# <br>
# 2) Are those restaurants getting any better over time?
# <br>
# 3) What does Yelp say about the worst restaurant in terms of star rating and reviews?
#
# Additional question by using the best restaurants recommended by Yelp,
# <br>Are the top 10 best restaurants recommended by Yelp compliant with the food safety regulation?
#
# By answering above research questions, I can find insights on which restaurants in New York City are complying with the food safety regulations and also which restaurants are favored by the customers. This insigt will be a sound grounding for me to recommend these restaurants to those who struggle with deciding where to eat outside the home. Additionally, I will be able to find out if those recommended restaurants keep their hygiene over the years constantly. On the other hand, the restaurants to avoid will be analyzed as well in the same way that I will perform for the recommended restaurants with opposite values for each parameter to consider. The answers to the research questions will be a great help for those who seek reasonable foundations to rely on when they eat out, instead of solely depending on lay opinions or reviews.

# %% [markdown]
# ## Data to be Used
#
# The first dataset containing the Department of Health and Mental Hygiene New York City Restaurant Inspection Results will be downloaded from NYC OpenData website in CSV format, and I will load this dataset into Jupyter notebook for analysis.
# Because of the limitations of Github repository(100MB), I truncated the dataset to contain the records from May 2017, and also deleted rows that contain missing values.
# <br>
# The second dataset containing the reviews of restaurants from Yelp.com will be read as JSON format accessible via the web API.
#
# #### Attribute information
#
# 1. CAMIS: Unique identifier for the establishment (restaurant)
# 2. DBA: Establishment (restaurant) name
# 3. BORO: Borough of establishment (restaurant) location
# 4. BUILDING: Building number for establishment (restaurant) location
# 5. STREET: Street name for establishment (restaurant) location
# 6. ZIPCODE: Zip code of establishment (restaurant) location
# 7. PHONE: Phone number
# 8. CUISINE DESCRIPTION: Establishment (restaurant) cuisine
# 9. INSPECTION DATE
# 10. ACTION: Action associated with each establishment (restaurant) inspection
# 11. VIOLATION CODE: Violation code associated with an establishment (restaurant) inspection
# 12. VIOLATION DESCRIPTION: Violation description associated with an establishment  (restaurant) inspection
# 13. CRITICAL FLAG: Indicator of critical violation
# 14. SCORE: Total score for a particular inspection
# <br>  Restaurants with a score between 0 and 13 points earn an A, those with 14 to 27 points receive a B and those with 28
# or more a C.
# 15. GRADE: Grade associated with the inspection<br>
# • N= Not Yet Graded<br>
# • A = Grade A<br>
# • B = Grade B<br>
# • C = Grade C<br>
# • Z = Grade Pending<br>
# • P=Grade Pending issued on re-opening following an initial inspection that resulted in a closure
#
# 16. GRADE DATE: Date when grade was issued to the establishment (restaurant)
# 17. RECORD DATE: Date record was added to dataset
# 18. INSPECTION TYPE: A combination of the inspection program and the type of inspection performed

# %% [markdown]
# ## References
#
# 1) DOHMH New York City Restaurant Inspection Results
# <br>
# https://data.cityofnewyork.us/Health/DOHMH-New-York-City-Restaurant-Inspection-Results/43nn-pn8j
#
# 2) Get started with the Yelp Fusion API
# <br>
# https://www.yelp.com/developers/documentation/v3/get_started
#
# 3) World Popultion Review
# <br>
# http://worldpopulationreview.com/us-cities/new-york-city-population/
#
# 4) Burdens abound, but NYC restaurants' numbers are growing
# <br>
# https://www.crainsnewyork.com/article/20180412/BLOGS01/180419940/burdens-abound-but-nyc-restaurants-numbers-are-growing
#
# 5) Don’t Eat Out as Often (188/365)
# <br>
# https://www.thesimpledollar.com/dont-eat-out-as-often-188365/
#
# 6) How we score and grade
# <br>
# https://www1.nyc.gov/assets/doh/downloads/pdf/rii/how-we-score-grade.pdf

# %% [markdown]
# ## Approach
#
# First of all, I will conduct EDA(exploratory data analysis) to describe and/or validate my dataset. After that, I will transform my datasets into appropriate format for analysis(Data Wrangling).
# <br>
# For recommended restaurants,
# <br>
# 1) What are the best restaurants that are compliant with the City and State food safety regulations?
# - I will extract the most recent inspection date, and then find the restaurants who received the lowest "Score" for the inspections. I will choose the top 5 restaurants.
#
# <br>
# 2) Are those restaurants getting better over time and/or keep hygiene constantly?
#
# - I will create the line plot by using the "Score"(dependent variable) and "Inspection Date"(independent variable) columns as respective variables to see the trends over time.
#
# <br>
# 3) What does Yelp say about the best restaurant in terms of star rating and review?
#
# - I will request data using Yelp API, which contains the star ratings and reveiws of the restaurant, by using the phone number and buisiness ID, respectively.
#
# - I will assess the star ratings and reviews and draw conclusions.
#
# For restaurants to avoid, I will conduct the same procedures as described above, using appropriate values for each parameter to consider. For example, I will use the highest "SCORE" to select the worst 5 restaurants in NYC.
#
# In addition, the dataset from Yelp with respective "best" and "worst" restaurants described above will include the latitude and longitude in one of the columns, "coordinates". By using the latitude and longitude, I will generate the map(geoplots) to locate the best and worst restaurants in New York City.
# <br>
# Finally, I will assess if the best restaurants recommended by Yelp are compliant with the food safety regulations.

# %% [markdown]
# ### Phase 1: Loading the data and Data wrangling

# %%
#importing necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#loading the data
df = pd.read_csv('https://raw.githubusercontent.com/mhan1/analytical-programming/master/NYC_RESTAURANTS.csv')

# %%
#sanity check
df.head()
# Out:
#       CAMIS                       DBA           BORO BUILDING  \
# 0  40366132  DENINO'S PIZZERIA TAVERN  STATEN ISLAND      524
# 1  40366132  DENINO'S PIZZERIA TAVERN  STATEN ISLAND      524
# 2  40367442        BUDDY'S WONDER BAR  STATEN ISLAND       17
# 3  40367442        BUDDY'S WONDER BAR  STATEN ISLAND       17
# 4  40367442        BUDDY'S WONDER BAR  STATEN ISLAND       17
#
#                  STREET  ZIPCODE       PHONE CUISINE DESCRIPTION  \
# 0  PORT RICHMOND AVENUE  10302.0  7184429401       Pizza/Italian
# 1  PORT RICHMOND AVENUE  10302.0  7184429401       Pizza/Italian
# 2       HARRISON AVENUE  10302.0  7184429768            American
# 3       HARRISON AVENUE  10302.0  7184429768            American
# 4       HARRISON AVENUE  10302.0  7184429768            American
#
#   INSPECTION DATE                                           ACTION  \
# 0        5/1/2017  Violations were cited in the following area(s).
# 1        5/1/2017  Violations were cited in the following area(s).
# 2        5/1/2017  Violations were cited in the following area(s).
# 3        5/1/2017  Violations were cited in the following area(s).
# 4        5/1/2017  Violations were cited in the following area(s).
#
#   VIOLATION CODE                              VIOLATION DESCRIPTION  \
# 0            02B        Hot food item not held at or above 140Âº F.
# 1            10F  Non-food contact surface improperly constructe...
# 2            04A  Food Protection Certificate not held by superv...
# 3            04L  Evidence of mice or live mice present in facil...
# 4            06D  Food contact surface not properly washed, rins...
#
#   CRITICAL FLAG  SCORE GRADE GRADE DATE RECORD DATE  \
# 0      Critical   10.0     A   5/1/2017    5/4/2019
# 1  Not Critical   10.0     A   5/1/2017    5/4/2019
# 2      Critical   27.0   NaN        NaN    5/4/2019
# 3      Critical   27.0   NaN        NaN    5/4/2019
# 4      Critical   27.0   NaN        NaN    5/4/2019
#
#                          INSPECTION TYPE
# 0       Cycle Inspection / Re-inspection
# 1       Cycle Inspection / Re-inspection
# 2  Cycle Inspection / Initial Inspection
# 3  Cycle Inspection / Initial Inspection
# 4  Cycle Inspection / Initial Inspection

# %%
#checking the number of rows and columns in df
df.shape
# Out:
# (263755, 18)

# %%
#cecking the columns in df
df.columns
# Out:
# Index(['CAMIS', 'DBA', 'BORO', 'BUILDING', 'STREET', 'ZIPCODE', 'PHONE',
#        'CUISINE DESCRIPTION', 'INSPECTION DATE', 'ACTION', 'VIOLATION CODE',
#        'VIOLATION DESCRIPTION', 'CRITICAL FLAG', 'SCORE', 'GRADE',
#        'GRADE DATE', 'RECORD DATE', 'INSPECTION TYPE'],
#       dtype='object')

# %%
#creating a pandas DataFrame with a subset of the columns in the dataset.
df1 = df[['DBA','BORO','BUILDING', 'STREET', 'PHONE', 'CUISINE DESCRIPTION', 'INSPECTION DATE', 
          'ACTION', 'VIOLATION DESCRIPTION', 'SCORE', 'GRADE']]
df1.head(3)
# Out:
#                         DBA           BORO BUILDING                STREET  \
# 0  DENINO'S PIZZERIA TAVERN  STATEN ISLAND      524  PORT RICHMOND AVENUE
# 1  DENINO'S PIZZERIA TAVERN  STATEN ISLAND      524  PORT RICHMOND AVENUE
# 2        BUDDY'S WONDER BAR  STATEN ISLAND       17       HARRISON AVENUE
#
#         PHONE CUISINE DESCRIPTION INSPECTION DATE  \
# 0  7184429401       Pizza/Italian        5/1/2017
# 1  7184429401       Pizza/Italian        5/1/2017
# 2  7184429768            American        5/1/2017
#
#                                             ACTION  \
# 0  Violations were cited in the following area(s).
# 1  Violations were cited in the following area(s).
# 2  Violations were cited in the following area(s).
#
#                                VIOLATION DESCRIPTION  SCORE GRADE
# 0        Hot food item not held at or above 140Âº F.   10.0     A
# 1  Non-food contact surface improperly constructe...   10.0     A
# 2  Food Protection Certificate not held by superv...   27.0   NaN

# %%
#printing the summary of df1
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263755 entries, 0 to 263754
# Data columns (total 11 columns):
# DBA                      263751 non-null object
# BORO                     263755 non-null object
# BUILDING                 263596 non-null object
# STREET                   263755 non-null object
# PHONE                    263742 non-null object
# CUISINE DESCRIPTION      263755 non-null object
# INSPECTION DATE          263755 non-null object
# ACTION                   263755 non-null object
# VIOLATION DESCRIPTION    258164 non-null object
# SCORE                    252774 non-null float64
# GRADE                    132573 non-null object
# dtypes: float64(1), object(10)
# memory usage: 22.1+ MB

# %%
#checking the first value of INSPECTION DATE column
df1['INSPECTION DATE'][0]
# Out:
# '5/1/2017'

# %%
#checking the data type of INSEPCTION DATE column first value
type(df1['INSPECTION DATE'][0])
# Out:
# str

# %%
#transforming the data type of INSPECTION DATE column into datetime
df1['INSPECTION DATE'] = pd.to_datetime(df['INSPECTION DATE'])
# Out:
# C:\Users\Minyeong\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#sanity check for the first value of INSPECTION DATE column
df1['INSPECTION DATE'][0]
# Out:
# Timestamp('2017-05-01 00:00:00')

# %%
#checking the data type after converting into datetime
type(df1['INSPECTION DATE'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
#checking the dataframe df1 summary
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263755 entries, 0 to 263754
# Data columns (total 11 columns):
# DBA                      263751 non-null object
# BORO                     263755 non-null object
# BUILDING                 263596 non-null object
# STREET                   263755 non-null object
# PHONE                    263742 non-null object
# CUISINE DESCRIPTION      263755 non-null object
# INSPECTION DATE          263755 non-null datetime64[ns]
# ACTION                   263755 non-null object
# VIOLATION DESCRIPTION    258164 non-null object
# SCORE                    252774 non-null float64
# GRADE                    132573 non-null object
# dtypes: datetime64[ns](1), float64(1), object(9)
# memory usage: 22.1+ MB

# %%
#chekcing the description of df1 dataframe
df1.describe()
# Out:
#                SCORE
# count  252774.000000
# mean       20.724153
# std        15.033151
# min        -1.000000
# 25%        11.000000
# 50%        16.000000
# 75%        26.000000
# max       166.000000

# %% [markdown]
# ### Phase 2:Perform exploratory data analysis(EDA) - show the distribution of data for each of the columns you selected and include text describing your EDA findings.

# %%
#descriptive statistics for df1 dataframe
df1.describe()
# Out:
#                SCORE
# count  252774.000000
# mean       20.724153
# std        15.033151
# min        -1.000000
# 25%        11.000000
# 50%        16.000000
# 75%        26.000000
# max       166.000000

# %%
#printing a concise summary of df1 dataframe
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263755 entries, 0 to 263754
# Data columns (total 11 columns):
# DBA                      263751 non-null object
# BORO                     263755 non-null object
# BUILDING                 263596 non-null object
# STREET                   263755 non-null object
# PHONE                    263742 non-null object
# CUISINE DESCRIPTION      263755 non-null object
# INSPECTION DATE          263755 non-null datetime64[ns]
# ACTION                   263755 non-null object
# VIOLATION DESCRIPTION    258164 non-null object
# SCORE                    252774 non-null float64
# GRADE                    132573 non-null object
# dtypes: datetime64[ns](1), float64(1), object(9)
# memory usage: 22.1+ MB

# %%
#checking columns
df1.columns
# Out:
# Index(['DBA', 'BORO', 'BUILDING', 'STREET', 'PHONE', 'CUISINE DESCRIPTION',
#        'INSPECTION DATE', 'ACTION', 'VIOLATION DESCRIPTION', 'SCORE', 'GRADE'],
#       dtype='object')

# %%
#renaming the 'DBA' and 'BORO' columns.
df1.rename(columns={'DBA':'RESTAURANT', 'BORO':'BOROUGH'}, inplace = True)
# Out:
# C:\Users\Minyeong\Anaconda3\lib\site-packages\pandas\core\frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
#checking the columns in df1
df1.columns
# Out:
# Index(['RESTAURANT', 'BOROUGH', 'BUILDING', 'STREET', 'PHONE',
#        'CUISINE DESCRIPTION', 'INSPECTION DATE', 'ACTION',
#        'VIOLATION DESCRIPTION', 'SCORE', 'GRADE'],
#       dtype='object')

# %%
#identifying missing values, displaying the columns that have null values
print(df1.isnull().any(axis=0))
# Out:
# RESTAURANT                True
# BOROUGH                  False
# BUILDING                  True
# STREET                   False
# PHONE                     True
# CUISINE DESCRIPTION      False
# INSPECTION DATE          False
# ACTION                   False
# VIOLATION DESCRIPTION     True
# SCORE                     True
# GRADE                     True
# dtype: bool

# %% [markdown]
# Based on above, DBA, BUILDING, PHONE, VIOLATION DESCRIPTION, SCORE, AND GRADE columns have null values.
# <br> According to "How we score and grade" by NYC Health department (https://www1.nyc.gov/assets/doh/downloads/pdf/rii/how-we-score-grade.pdf),
# <br> A restaurant has two chances to earn an A in every inspection
# cycle. If it doesn’t earn an A on the first inspection, it’s scored but
# ungraded. An inspector goes back to the restaurant
# unannounced, typically within a month, to inspect it again
# and the re-inspection is graded. If the grade is a B or C, the
# restaurant will receive a grade card and a grade pending card. It
# can post either card until it has an opportunity to be heard at
# the Office of Administrative Trials and Hearings Health
# Tribunal.
# <br>
# Hence, the null values in GRADE columns can be either "scored but ungraded", or in the "pending" status. Either way, these restaurants did not receive A grade on the first inspection. Therefore, I decided to leave those "null" values in the GRADE column as these indicate those restaurants are not "A" grade restaurants, at least, yet.

# %%
#sanity check
df1.head(3)
# Out:
#                  RESTAURANT        BOROUGH BUILDING                STREET  \
# 0  DENINO'S PIZZERIA TAVERN  STATEN ISLAND      524  PORT RICHMOND AVENUE
# 1  DENINO'S PIZZERIA TAVERN  STATEN ISLAND      524  PORT RICHMOND AVENUE
# 2        BUDDY'S WONDER BAR  STATEN ISLAND       17       HARRISON AVENUE
#
#         PHONE CUISINE DESCRIPTION INSPECTION DATE  \
# 0  7184429401       Pizza/Italian      2017-05-01
# 1  7184429401       Pizza/Italian      2017-05-01
# 2  7184429768            American      2017-05-01
#
#                                             ACTION  \
# 0  Violations were cited in the following area(s).
# 1  Violations were cited in the following area(s).
# 2  Violations were cited in the following area(s).
#
#                                VIOLATION DESCRIPTION  SCORE GRADE
# 0        Hot food item not held at or above 140Âº F.   10.0     A
# 1  Non-food contact surface improperly constructe...   10.0     A
# 2  Food Protection Certificate not held by superv...   27.0   NaN

# %% [markdown]
# ### Distribution of 'BOROUGH'

# %%
#checking the BOROUGH column summary information
df1['BOROUGH'].describe()
# Out:
# count        263755
# unique            5
# top       MANHATTAN
# freq         103723
# Name: BOROUGH, dtype: object

# %%
#checking unique values in BOROUGH column
df1['BOROUGH'].unique()
# Out:
# array(['STATEN ISLAND', 'MANHATTAN', 'QUEENS', 'BROOKLYN', 'BRONX'],
#       dtype=object)

# %%
#getting the value counts for the 'BOROUGH' variable, which is categorical data type.
df1['BOROUGH'].value_counts()
# Out:
# MANHATTAN        103723
# BROOKLYN          66650
# QUEENS            60859
# BRONX             23289
# STATEN ISLAND      9234
# Name: BOROUGH, dtype: int64

# %%
#creating a bar plot of the 'BOROUGH' variable's value counts
df1['BOROUGH'].value_counts().plot.bar(title = "Freq Dist of BOROUGH");

# %% [markdown]
# Based on above, there are 103723 of inspected restaurants' records in Manhattan, which is the largest counts, and there are 9234 of inspected restaurants' records in STATEN ISLAND which is the smallest counts in the dataset.

# %% [markdown]
# ### Distribution of 'RESTAURANT'

# %%
#checking the RESTAURANT column summary information
df1['RESTAURANT'].describe()
# Out:
# count             263751
# unique             20640
# top       DUNKIN' DONUTS
# freq                2438
# Name: RESTAURANT, dtype: object

# %%
#checking unique values in RESTAURANT column
df1['RESTAURANT'].unique()
# Out:
# array(["DENINO'S PIZZERIA TAVERN", "BUDDY'S WONDER BAR",
#        'ASTRO RESTAURANT', ..., 'HALO BISTRO CAFE', 'GRUIT',
#        'WHISTLE & FIZZ'], dtype=object)

# %%
#getting the value counts for the 'RESTAURANT' variable, which is categorical data type.
df1['RESTAURANT'].value_counts()
# Out:
# DUNKIN' DONUTS                               2438
# SUBWAY                                       2014
# STARBUCKS                                    1420
# MCDONALD'S                                   1271
# KENNEDY FRIED CHICKEN                         904
# CROWN FRIED CHICKEN                           732
# DUNKIN' DONUTS, BASKIN ROBBINS                710
# BURGER KING                                   653
# DOMINO'S                                      630
# GOLDEN KRUST CARIBBEAN BAKERY & GRILL         557
# POPEYES LOUISIANA KITCHEN                     445
# KFC                                           420
# CHIPOTLE MEXICAN GRILL                        407
# DUNKIN DONUTS                                 339
# LE PAIN QUOTIDIEN                             310
# CHECKERS                                      283
# VIVI BUBBLE TEA                               259
# WENDY'S                                       252
# PARIS BAGUETTE                                246
# PRET A MANGER                                 238
# BAREBURGER                                    226
# CARVEL ICE CREAM                              211
# JUST SALAD                                    211
# BREAD & BUTTER                                195
# IHOP                                          194
# JOE & THE JUICE                               187
# BOSTON MARKET                                 184
# PAPA JOHN'S                                   179
# LITTLE CAESARS                                171
# TEXAS CHICKEN & BURGERS                       168
#                                              ...
# SALT BRICK TAVERN                               1
# New Golden Restaurant                           1
# CHU ROS THAI                                    1
# R.J.'S PLACE                                    1
# LEONELLI TABERNA                                1
# BEACON THEATRE (LOGE STAIRS BAR)                1
# NEW YORK SWEETS                                 1
# CHINA SING RESTAURANT                           1
# F.B. & J                                        1
# ATLANTIC FREEZE                                 1
# ROMANCE BAR AND RESTAURANT                      1
# ANGELO GORDON                                   1
# ELECTRIC ROOM                                   1
# DAVID'S K DELI                                  1
# HAPPY FIN POKE                                  1
# SHARKEY'S SQUARE                                1
# SHUT EYE                                        1
# THE FAT CARDINAL BAKERY                         1
# BEACON THEATRE (ORCHESTRA BAR/MAIN FLOOR)       1
# UPTOWN POKE                                     1
# SMÃR                                           1
# BEMBE                                           1
# FUSCO                                           1
# Garden Market 36/37                             1
# JAMAICAN BEST CORP                              1
# BT3 AISLE A                                     1
# PRESS DINING & BEER ROOM                        1
# MILK BURGER                                     1
# HO'BRAH                                         1
# EL PAILON                                       1
# Name: RESTAURANT, Length: 20640, dtype: int64

# %% [markdown]
# Since there are total 20640 unique restaurants in the dataset as shown above, I will not plot the bar chart to show the distribution. Dunkin' donuts are the most frequent restaurant in the dataset, followed by Subway, Starbucks, and Mcdonald's.

# %% [markdown]
# ### Distribution of SCORE

# %%
#checking the SCORE column summary information
df1['SCORE'].describe()
# Out:
# count    252774.000000
# mean         20.724153
# std          15.033151
# min          -1.000000
# 25%          11.000000
# 50%          16.000000
# 75%          26.000000
# max         166.000000
# Name: SCORE, dtype: float64

# %%
df1['SCORE'].unique()
# Out:
# array([ 10.,  27.,  13.,   4.,   7.,   9.,   3.,  nan,  12.,  11.,   6.,
#         43.,   2.,  18.,  22.,  14.,  19.,  23.,   5.,  15.,  16.,  37.,
#         28.,  25.,   8.,  17.,  42.,  32.,  20.,  33.,  79.,  36.,   0.,
#         39.,  26.,  34.,  24.,  30.,  21.,  44.,  62.,  29.,  31.,  35.,
#         40.,  66.,  41., 109.,  47.,  68.,  45.,  38.,  48.,  65.,  46.,
#         57.,  63.,  64.,  56.,  50.,  53.,  49.,  69.,  76.,  55., 117.,
#         72.,  73.,  70.,  -1.,  51.,  61.,  52.,  59.,  85.,  58.,  78.,
#         71.,  82.,  77.,  74.,  87.,  60.,  67.,  83.,  84.,  54.,  89.,
#         90.,  75., 151.,  91., 110.,  81., 120.,  92.,  86., 103.,  94.,
#         99., 135., 137.,  80., 115., 111., 124., 114., 116.,  88., 122.,
#        101.,  96., 104.,  93., 155., 140.,  98., 141., 112., 119., 132.,
#        106.,  97., 105., 102., 152., 100.,  95., 107., 129., 136., 131.,
#        108., 166.])

# %%
#checking the null values
df1['SCORE'].isnull().any(axis=0)
# Out:
# True

# %%
#converting the null values into 0
df1["SCORE"].fillna("0", inplace = True)
# Out:
# C:\Users\Minyeong\Anaconda3\lib\site-packages\pandas\core\generic.py:5434: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
df1.head(2)
# Out:
#                  RESTAURANT        BOROUGH BUILDING                STREET  \
# 0  DENINO'S PIZZERIA TAVERN  STATEN ISLAND      524  PORT RICHMOND AVENUE
# 1  DENINO'S PIZZERIA TAVERN  STATEN ISLAND      524  PORT RICHMOND AVENUE
#
#         PHONE CUISINE DESCRIPTION INSPECTION DATE  \
# 0  7184429401       Pizza/Italian      2017-05-01
# 1  7184429401       Pizza/Italian      2017-05-01
#
#                                             ACTION  \
# 0  Violations were cited in the following area(s).
# 1  Violations were cited in the following area(s).
#
#                                VIOLATION DESCRIPTION SCORE GRADE
# 0        Hot food item not held at or above 140Âº F.    10     A
# 1  Non-food contact surface improperly constructe...    10     A

# %%
#converting SCORE column data type into integer.
df1.SCORE = df1.SCORE.astype(int)
# Out:
# C:\Users\Minyeong\Anaconda3\lib\site-packages\pandas\core\generic.py:4405: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
#histogram of 'SCORE' variable which is numeric data type.
sns.distplot(df1.SCORE)
plt.title('Distribution of SCORE')
# Out:
# C:\Users\Minyeong\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0.5, 1.0, 'Distribution of SCORE')

# %%
sns.boxplot(df1.SCORE, orient = 'v', width=0.2)
plt.title('Boxplot of SCORE')
# Out:
# Text(0.5, 1.0, 'Boxplot of SCORE')

# %%
#checking the SCORE column summary information
df1['SCORE'].describe()
# Out:
# count    263755.000000
# mean         19.861337
# std          15.288014
# min          -1.000000
# 25%          10.000000
# 50%          14.000000
# 75%          26.000000
# max         166.000000
# Name: SCORE, dtype: float64

# %% [markdown]
# Based on above, SCORE variable is right-skewed as the mean value is larger than the median. The mean score is 19.86, which indicates GRADE B.

# %% [markdown]
# ### Distribution of GRADE

# %%
#checking the GRADE column summary information
df1['GRADE'].describe()
# Out:
# count     132573
# unique         7
# top            A
# freq      102827
# Name: GRADE, dtype: object

# %%
#checking unique values in GRADE column
df1['GRADE'].unique()
# Out:
# array(['A', nan, 'B', 'P', 'C', 'Z', 'Not Yet Graded', 'G'], dtype=object)

# %%
#getting the value counts for the 'GRADE' variable, which is categorical data type.
df1['GRADE'].value_counts()
# Out:
# A                 102827
# B                  16420
# C                   5973
# Z                   3101
# Not Yet Graded      2373
# P                   1874
# G                      5
# Name: GRADE, dtype: int64

# %%
#creating a bar plot of the 'GRADE' variable's value counts
df1['GRADE'].value_counts().plot.bar(title = "Freq Dist of GRADE");

# %% [markdown]
# Based on above, 102827 of inspected restaurants received A grade, which is the most frequent grade, and there are some pending grades such as Z, P, G, and "Not Yet Graded". The details about how Health department score and grade was described above, and also it can be found in the link: https://www1.nyc.gov/assets/doh/downloads/pdf/rii/how-we-score-grade.pdf

# %% [markdown]
# ### Phase 3: Find the restaurants that received the lowest SCORE and the best GRADE in NYC.

# %%
#sanity check
df1.head(2)
# Out:
#                  RESTAURANT        BOROUGH BUILDING                STREET  \
# 0  DENINO'S PIZZERIA TAVERN  STATEN ISLAND      524  PORT RICHMOND AVENUE
# 1  DENINO'S PIZZERIA TAVERN  STATEN ISLAND      524  PORT RICHMOND AVENUE
#
#         PHONE CUISINE DESCRIPTION INSPECTION DATE  \
# 0  7184429401       Pizza/Italian      2017-05-01
# 1  7184429401       Pizza/Italian      2017-05-01
#
#                                             ACTION  \
# 0  Violations were cited in the following area(s).
# 1  Violations were cited in the following area(s).
#
#                                VIOLATION DESCRIPTION  SCORE GRADE
# 0        Hot food item not held at or above 140Âº F.     10     A
# 1  Non-food contact surface improperly constructe...     10     A

# %%
#checking the INSPECTIN DATE column
df1['INSPECTION DATE'].describe()
# Out:
# count                  263755
# unique                    644
# top       2019-03-28 00:00:00
# freq                      996
# first     2017-05-01 00:00:00
# last      2019-05-02 00:00:00
# Name: INSPECTION DATE, dtype: object

# %%
#finding the most recent inspection date
df1['INSPECTION DATE'].sort_values(ascending=False).head()
# Out:
# 263754   2019-05-02
# 263420   2019-05-02
# 263407   2019-05-02
# 263408   2019-05-02
# 263409   2019-05-02
# Name: INSPECTION DATE, dtype: datetime64[ns]

# %% [markdown]
# Based on above, 2019-05-02 is the most recent INSPECTION DATE in the dataset, so I will use this date to find the "best" restaurant based on the SCORE and GRADE in each borough.

# %%
#extracting the data which was inspected on 2019-05-02
df2 = pd.DataFrame(df1.loc[df1['INSPECTION DATE'] == '2019-05-02'])
df2.head(3)
# Out:
#                       RESTAURANT    BOROUGH BUILDING             STREET  \
# 263248  THE NEW AMITY RESTAURANT  MANHATTAN     1134     MADISON AVENUE
# 263249  THE NEW AMITY RESTAURANT  MANHATTAN     1134     MADISON AVENUE
# 263250            WESTERN BAKERY     QUEENS    22813  MERRICK BOULEVARD
#
#              PHONE CUISINE DESCRIPTION INSPECTION DATE  \
# 263248  2128613255            American      2019-05-02
# 263249  2128613255            American      2019-05-02
# 263250  7185253201           Caribbean      2019-05-02
#
#                                                  ACTION  \
# 263248  Violations were cited in the following area(s).
# 263249  Violations were cited in the following area(s).
# 263250  Violations were cited in the following area(s).
#
#                                     VIOLATION DESCRIPTION  SCORE GRADE
# 263248        Hot food item not held at or above 140Âº F.      9     A
# 263249  Mechanical or natural ventilation system not p...      9     A
# 263250  Food not cooled by an approved method whereby ...      9     A

# %%
#checking the number of rows and columns
df2.shape
# Out:
# (507, 11)

# %%
#grouping by 'BOROUGH' and 'RESTAURANT', and then calculating the mean of 'SCORE' column.
grouped_df2 = df2.groupby(['BOROUGH', 'RESTAURANT', 'GRADE'])['SCORE'].agg([('Average Score', 'mean')]).sort_values(by=['Average Score'], ascending=True)
grouped_df2.head(5)
# Out:
#                                          Average Score
# BOROUGH       RESTAURANT          GRADE
# MANHATTAN     MILK BAR NOLITA     A                  2
# STATEN ISLAND SUBWAY              A                  2
# BROOKLYN      CROWN FRIED CHICKEN A                  2
# QUEENS        CAFE TO GO          A                  2
# MANHATTAN     NATHAN'S FAMOUS     A                  2

# %% [markdown]
# Recommended restaurants: Based on above table, MILK BAR NOLITA, SUBWAY, CROWN FRIED CHICKEN, CAFE TO GO, NATHAN'S FAMOUS are the best 5 restaurants in terms of lowest SCORE as of 2019-05-02, which means they are compliant with the City and State food safety regulations.

# %% [markdown]
# ### Phase 4: Find the restaurants that received the highest SCORE and the worst GRADE in NYC.

# %%
grouped_df2.tail(5)
# Out:
#                                                         Average Score
# BOROUGH   RESTAURANT                    GRADE
# MANHATTAN LUCKY                         Z                          39
# BROOKLYN  TOBY'S ESTATE COFFEE BUSHWICK Z                          40
# MANHATTAN GOURMET PARK                  Z                          43
# BROOKLYN  EMMY SQUARED                  Z                          51
# QUEENS    SOUTHERN GIRLS SOUL FOOD      Not Yet Graded            119

# %% [markdown]
# Restaurants to avoid: Based on above table, SOUTHERN GIRLS SOUL FOOD  is the worst restaurant scoring 119 as of 2019-05-02, followed by EMMY SQUARED, GOURMET PARK, TOBY'S ESTATE COFFEE BUSHWICK, and LUCKY. They are definitely not compliant with the City and State food safety regulations, and we need to avoid these restaurants.

# %% [markdown]
# ### Phase 5: Assess the best and the worst restaurants' compliance with the food safety regulations over time, respectively.

# %%
#replacing the charcter(') into (-) in RESTAURANT column
df1['RESTAURANT'] = df1['RESTAURANT'].str.replace("'", "-")
# Out:
# C:\Users\Minyeong\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#extracting the data which contain the best restaurants
df2_best = df1[df1['RESTAURANT'].isin(['NATHAN-S FAMOUS', 'CAFE TO GO', 'CROWN FRIED CHICKEN', 'SUBWAY', 'MILK BAR NOLITA'])]
df2_best
# Out:
#                  RESTAURANT        BOROUGH BUILDING                   STREET  \
# 435                  SUBWAY         QUEENS    11814           JAMAICA AVENUE
# 436                  SUBWAY         QUEENS    11814           JAMAICA AVENUE
# 437                  SUBWAY         QUEENS    11814           JAMAICA AVENUE
# 561                  SUBWAY         QUEENS    13240         METROPOLITAN AVE
# 562                  SUBWAY         QUEENS    13240         METROPOLITAN AVE
# 756                  SUBWAY      MANHATTAN       21         EAST  118 STREET
# 761         NATHAN-S FAMOUS       BROOKLYN      569            MYRTLE AVENUE
# 762         NATHAN-S FAMOUS       BROOKLYN      569            MYRTLE AVENUE
# 896     CROWN FRIED CHICKEN       BROOKLYN      577               SUTTER AVE
# 897     CROWN FRIED CHICKEN       BROOKLYN      577               SUTTER AVE
# 898     CROWN FRIED CHICKEN       BROOKLYN      577               SUTTER AVE
# 899     CROWN FRIED CHICKEN       BROOKLYN      577               SUTTER AVE
# 900     CROWN FRIED CHICKEN       BROOKLYN      577               SUTTER AVE
# 913                  SUBWAY          BRONX       91               E 161ST ST
# 1097    CROWN FRIED CHICKEN         QUEENS    20420          HILLSIDE AVENUE
# 1098    CROWN FRIED CHICKEN         QUEENS    20420          HILLSIDE AVENUE
# 1465                 SUBWAY      MANHATTAN     1661                 1 AVENUE
# 1466                 SUBWAY      MANHATTAN     1661                 1 AVENUE
# 1467                 SUBWAY      MANHATTAN     1661                 1 AVENUE
# 1514                 SUBWAY      MANHATTAN      692         LEXINGTON AVENUE
# 1515                 SUBWAY      MANHATTAN      692         LEXINGTON AVENUE
# 1516                 SUBWAY      MANHATTAN      692         LEXINGTON AVENUE
# 1517                 SUBWAY      MANHATTAN      692         LEXINGTON AVENUE
# 1518                 SUBWAY      MANHATTAN      692         LEXINGTON AVENUE
# 1522                 SUBWAY      MANHATTAN      223                 AVENUE B
# 1523                 SUBWAY      MANHATTAN      223                 AVENUE B
# 1524                 SUBWAY      MANHATTAN      223                 AVENUE B
# 1670    CROWN FRIED CHICKEN       BROOKLYN      167       MARCUS GARVEY BLVD
# 1671    CROWN FRIED CHICKEN       BROOKLYN      167       MARCUS GARVEY BLVD
# 1856                 SUBWAY       BROOKLYN     1875          NOSTRAND AVENUE
# ...                     ...            ...      ...                      ...
# 261482               SUBWAY         QUEENS    27106               UNION TPKE
# 261483               SUBWAY         QUEENS    27106               UNION TPKE
# 261490               SUBWAY      MANHATTAN      113                E 14TH ST
# 261491               SUBWAY      MANHATTAN      113                E 14TH ST
# 261849               SUBWAY      MANHATTAN    48991                 3 AVENUE
# 261850               SUBWAY      MANHATTAN    48991                 3 AVENUE
# 261908               SUBWAY         QUEENS     4024  COLLEGE POINT BOULEVARD
# 261909               SUBWAY         QUEENS     4024  COLLEGE POINT BOULEVARD
# 261910               SUBWAY         QUEENS     4024  COLLEGE POINT BOULEVARD
# 261978               SUBWAY       BROOKLYN      525                  5TH AVE
# 262401  CROWN FRIED CHICKEN       BROOKLYN      407             SARATOGA AVE
# 262402  CROWN FRIED CHICKEN       BROOKLYN      407             SARATOGA AVE
# 262403  CROWN FRIED CHICKEN       BROOKLYN      407             SARATOGA AVE
# 262404  CROWN FRIED CHICKEN       BROOKLYN      407             SARATOGA AVE
# 262523               SUBWAY       BROOKLYN     1503      SHEEPSHEAD BAY ROAD
# 262524               SUBWAY       BROOKLYN     1503      SHEEPSHEAD BAY ROAD
# 262678               SUBWAY      MANHATTAN      563             LENOX AVENUE
# 262679               SUBWAY      MANHATTAN      563             LENOX AVENUE
# 262724               SUBWAY       BROOKLYN      139          FLATBUSH AVENUE
# 262725               SUBWAY       BROOKLYN      139          FLATBUSH AVENUE
# 262726               SUBWAY       BROOKLYN      139          FLATBUSH AVENUE
# 262895               SUBWAY         QUEENS      233            BEACH 20TH ST
# 262896               SUBWAY         QUEENS      233            BEACH 20TH ST
# 263288      NATHAN-S FAMOUS      MANHATTAN        2               PENN PLAZA
# 263309               SUBWAY      MANHATTAN        1               PENN PLAZA
# 263313               SUBWAY  STATEN ISLAND      680         ARTHUR KILL ROAD
# 263418           CAFE TO GO         QUEENS     2858                  32ND ST
# 263538  CROWN FRIED CHICKEN       BROOKLYN     3149                FULTON ST
# 263539  CROWN FRIED CHICKEN       BROOKLYN     3149                FULTON ST
# 263559      MILK BAR NOLITA      MANHATTAN      246                  MOTT ST
#
#              PHONE             CUISINE DESCRIPTION INSPECTION DATE  \
# 435     7184874079  Sandwiches/Salads/Mixed Buffet      2017-05-02
# 436     7184874079  Sandwiches/Salads/Mixed Buffet      2017-05-02
# 437     7184874079  Sandwiches/Salads/Mixed Buffet      2017-05-02
# 561     7185269800                      Sandwiches      2017-05-02
# 562     7185269800                      Sandwiches      2017-05-02
# 756     2122890142                      Sandwiches      2017-05-03
# 761     7187833744                         Hotdogs      2017-05-03
# 762     7187833744                         Hotdogs      2017-05-03
# 896     3474058729                         Chicken      2017-05-03
# 897     3474058729                         Chicken      2017-05-03
# 898     3474058729                         Chicken      2017-05-03
# 899     3474058729                         Chicken      2017-05-03
# 900     3474058729                         Chicken      2017-05-03
# 913     7185889100                      Sandwiches      2017-05-03
# 1097    7184647883                        American      2017-05-04
# 1098    7184647883                        American      2017-05-04
# 1465    2129873839                      Sandwiches      2017-05-05
# 1466    2129873839                      Sandwiches      2017-05-05
# 1467    2129873839                      Sandwiches      2017-05-05
# 1514    2123171859  Sandwiches/Salads/Mixed Buffet      2017-05-05
# 1515    2123171859  Sandwiches/Salads/Mixed Buffet      2017-05-05
# 1516    2123171859  Sandwiches/Salads/Mixed Buffet      2017-05-05
# 1517    2123171859  Sandwiches/Salads/Mixed Buffet      2017-05-05
# 1518    2123171859  Sandwiches/Salads/Mixed Buffet      2017-05-05
# 1522    2122604206                      Sandwiches      2017-05-05
# 1523    2122604206                      Sandwiches      2017-05-05
# 1524    2122604206                      Sandwiches      2017-05-05
# 1670    7182246030                         Chicken      2017-05-05
# 1671    7182246030                         Chicken      2017-05-05
# 1856    6464841708                      Sandwiches      2017-05-09
# ...            ...                             ...             ...
# 261482  7183470477                      Sandwiches      2019-04-29
# 261483  7183470477                      Sandwiches      2019-04-29
# 261490  2127777088                      Sandwiches      2019-04-29
# 261491  2127777088                      Sandwiches      2019-04-29
# 261849  2122132228  Sandwiches/Salads/Mixed Buffet      2019-04-30
# 261850  2122132228  Sandwiches/Salads/Mixed Buffet      2019-04-30
# 261908  7184604700  Sandwiches/Salads/Mixed Buffet      2019-04-30
# 261909  7184604700  Sandwiches/Salads/Mixed Buffet      2019-04-30
# 261910  7184604700  Sandwiches/Salads/Mixed Buffet      2019-04-30
# 261978  7184992207  Sandwiches/Salads/Mixed Buffet      2019-04-30
# 262401  7185766116                        American      2019-04-30
# 262402  7185766116                        American      2019-04-30
# 262403  7185766116                        American      2019-04-30
# 262404  7185766116                        American      2019-04-30
# 262523  7188919188                      Sandwiches      2019-05-01
# 262524  7188919188                      Sandwiches      2019-05-01
# 262678  2128620104                      Sandwiches      2019-05-01
# 262679  2128620104                      Sandwiches      2019-05-01
# 262724  7182307703                      Sandwiches      2019-05-01
# 262725  7182307703                      Sandwiches      2019-05-01
# 262726  7182307703                      Sandwiches      2019-05-01
# 262895  7183373087  Sandwiches/Salads/Mixed Buffet      2019-05-01
# 262896  7183373087  Sandwiches/Salads/Mixed Buffet      2019-05-01
# 263288  2126300320                         Hotdogs      2019-05-02
# 263309  2122394212                      Sandwiches      2019-05-02
# 263313  347_215_29                      Sandwiches      2019-05-02
# 263418  7187212848                        American      2019-05-02
# 263538  7182352819                         Chicken      2019-05-02
# 263539  7182352819                         Chicken      2019-05-02
# 263559  3472425762                CafÃ©/Coffee/Tea      2019-05-02
#
#                                                  ACTION  \
# 435     Violations were cited in the following area(s).
# 436     Violations were cited in the following area(s).
# 437     Violations were cited in the following area(s).
# 561     Violations were cited in the following area(s).
# 562     Violations were cited in the following area(s).
# 756     Violations were cited in the following area(s).
# 761     Violations were cited in the following area(s).
# 762     Violations were cited in the following area(s).
# 896     Violations were cited in the following area(s).
# 897     Violations were cited in the following area(s).
# 898     Violations were cited in the following area(s).
# 899     Violations were cited in the following area(s).
# 900     Violations were cited in the following area(s).
# 913     Violations were cited in the following area(s).
# 1097    Violations were cited in the following area(s).
# 1098    Violations were cited in the following area(s).
# 1465    Violations were cited in the following area(s).
# 1466    Violations were cited in the following area(s).
# 1467    Violations were cited in the following area(s).
# 1514    Violations were cited in the following area(s).
# 1515    Violations were cited in the following area(s).
# 1516    Violations were cited in the following area(s).
# 1517    Violations were cited in the following area(s).
# 1518    Violations were cited in the following area(s).
# 1522    Violations were cited in the following area(s).
# 1523    Violations were cited in the following area(s).
# 1524    Violations were cited in the following area(s).
# 1670    Violations were cited in the following area(s).
# 1671    Violations were cited in the following area(s).
# 1856    Violations were cited in the following area(s).
# ...                                                 ...
# 261482  Violations were cited in the following area(s).
# 261483  Violations were cited in the following area(s).
# 261490  Violations were cited in the following area(s).
# 261491  Violations were cited in the following area(s).
# 261849  Violations were cited in the following area(s).
# 261850  Violations were cited in the following area(s).
# 261908  Violations were cited in the following area(s).
# 261909  Violations were cited in the following area(s).
# 261910  Violations were cited in the following area(s).
# 261978  Violations were cited in the following area(s).
# 262401  Violations were cited in the following area(s).
# 262402  Violations were cited in the following area(s).
# 262403  Violations were cited in the following area(s).
# 262404  Violations were cited in the following area(s).
# 262523  Violations were cited in the following area(s).
# 262524  Violations were cited in the following area(s).
# 262678  Violations were cited in the following area(s).
# 262679  Violations were cited in the following area(s).
# 262724  Violations were cited in the following area(s).
# 262725  Violations were cited in the following area(s).
# 262726  Violations were cited in the following area(s).
# 262895  Violations were cited in the following area(s).
# 262896  Violations were cited in the following area(s).
# 263288  Violations were cited in the following area(s).
# 263309  Violations were cited in the following area(s).
# 263313  Violations were cited in the following area(s).
# 263418  Violations were cited in the following area(s).
# 263538  Violations were cited in the following area(s).
# 263539  Violations were cited in the following area(s).
# 263559  Violations were cited in the following area(s).
#
#                                     VIOLATION DESCRIPTION  SCORE GRADE
# 435           Hot food item not held at or above 140Âº F.     17   NaN
# 436     Evidence of mice or live mice present in facil...     17   NaN
# 437     Facility not vermin proof. Harborage or condit...     17   NaN
# 561     Evidence of mice or live mice present in facil...      9   NaN
# 562     Facility not vermin proof. Harborage or condit...      9   NaN
# 756     Food contact surface not properly washed, rins...      5     A
# 761     Food contact surface not properly washed, rins...      7     A
# 762     Non-food contact surface improperly constructe...      7     A
# 896     Evidence of rats or live rats present in facil...     21   NaN
# 897     Evidence of mice or live mice present in facil...     21   NaN
# 898     Food contact surface not properly washed, rins...     21   NaN
# 899     Facility not vermin proof. Harborage or condit...     21   NaN
# 900     Non-food contact surface improperly constructe...     21   NaN
# 913     Non-food contact surface improperly constructe...      4     A
# 1097    Non-food contact surface improperly constructe...      4     A
# 1098    Single service item reused, improperly stored,...      4     A
# 1465    Food Protection Certificate not held by superv...     19     B
# 1466    Evidence of mice or live mice present in facil...     19     B
# 1467    Facility not vermin proof. Harborage or condit...     19     B
# 1514    Filth flies or food/refuse/sewage-associated (...     23   NaN
# 1515    Food not protected from potential source of co...     23   NaN
# 1516    Food contact surface not properly washed, rins...     23   NaN
# 1517    Facility not vermin proof. Harborage or condit...     23   NaN
# 1518    Toilet facility not maintained and provided wi...     23   NaN
# 1522    Food contact surface not properly washed, rins...      9     A
# 1523    Plumbing not properly installed or maintained;...      9     A
# 1524    Non-food contact surface improperly constructe...      9     A
# 1670    Sanitized equipment or utensil, including in-u...      8     A
# 1671    Non-food contact surface improperly constructe...      8     A
# 1856    Evidence of mice or live mice present in facil...     17   NaN
# ...                                                   ...    ...   ...
# 261482  Plumbing not properly installed or maintained;...      6     A
# 261483  Non-food contact surface improperly constructe...      6     A
# 261490  Cold food item held above 41Âº F (smoked fish ...     12     A
# 261491  Evidence of mice or live mice present in facil...     12     A
# 261849  Food contact surface not properly washed, rins...     12     A
# 261850  Sanitized equipment or utensil, including in-u...     12     A
# 261908  Plumbing not properly installed or maintained;...      6     A
# 261909  Non-food contact surface improperly constructe...      6     A
# 261910              Current letter grade card not posted.      0   NaN
# 261978                       Thawing procedures improper.      2     A
# 262401  Evidence of mice or live mice present in facil...     21     Z
# 262402  Food not protected from potential source of co...     21     Z
# 262403  Facility not vermin proof. Harborage or condit...     21     Z
# 262404  Non-food contact surface improperly constructe...     21     Z
# 262523  Food contact surface not properly washed, rins...      8     A
# 262524  Non-food contact surface improperly constructe...      8     A
# 262678  Food not protected from potential source of co...      7     A
# 262679  Non-food contact surface improperly constructe...      7     A
# 262724  Food contact surface not properly washed, rins...      9     A
# 262725  Non-food contact surface improperly constructe...      9     A
# 262726  ''''Wash hands sign not posted at hand wash f...      9     A
# 262895  Food worker does not use proper utensil to eli...     12     A
# 262896  Food contact surface not properly washed, rins...     12     A
# 263288  Non-food contact surface improperly constructe...      2     A
# 263309  Food not protected from potential source of co...      6     A
# 263313  Non-food contact surface improperly constructe...      2     A
# 263418  Non-food contact surface improperly constructe...      2     A
# 263538  Non-food contact surface improperly constructe...      2     A
# 263539                                                NaN      2     A
# 263559  Non-food contact surface improperly constructe...      2     A
#
# [2811 rows x 11 columns]

# %%
#extracting the year from 'INSPECTINO DATE' column
df2_best['INSPECTION DATE'] = df2_best['INSPECTION DATE'].map(lambda x: x.year)
# Out:
# C:\Users\Minyeong\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#creating a line chart to visualize the trend
plt.figure(figsize=(15,12))
sns.pointplot(x='INSPECTION DATE', y='SCORE', hue='RESTAURANT', data=df2_best);

# %% [markdown]
# Based on above line chart, MILK BAR NOLITA, NATHAN-S FAMOUS, CROWN FRIEND CHICKEN restaurants have improved their compliance with the City and State food safety regulations since 2018. SUBWAY and CAFE TO GO have not been improving their compliance with the food safety regulations since 2017, even though they received A grade in 2019.

# %%
#extracting the data which contain the worst restaurants
df2_worst = df1[df1['RESTAURANT'].isin(['LUCKY', 'TOBY-S ESTATE COFFEE BUSHWICK', 'GOURMET PARK', 
                                        'EMMY SQUARED', 'SOUTHERN GIRLS SOUL FOOD'])]
df2_worst
# Out:
#                            RESTAURANT    BOROUGH BUILDING        STREET  \
# 59331                    EMMY SQUARED   BROOKLYN      364      GRAND ST
# 59332                    EMMY SQUARED   BROOKLYN      364      GRAND ST
# 113195       SOUTHERN GIRLS SOUL FOOD     QUEENS    21828  MERRICK BLVD
# 113196       SOUTHERN GIRLS SOUL FOOD     QUEENS    21828  MERRICK BLVD
# 113197       SOUTHERN GIRLS SOUL FOOD     QUEENS    21828  MERRICK BLVD
# 113198       SOUTHERN GIRLS SOUL FOOD     QUEENS    21828  MERRICK BLVD
# 113199       SOUTHERN GIRLS SOUL FOOD     QUEENS    21828  MERRICK BLVD
# 113200       SOUTHERN GIRLS SOUL FOOD     QUEENS    21828  MERRICK BLVD
# 113201       SOUTHERN GIRLS SOUL FOOD     QUEENS    21828  MERRICK BLVD
# 115991       SOUTHERN GIRLS SOUL FOOD     QUEENS    21828  MERRICK BLVD
# 115992       SOUTHERN GIRLS SOUL FOOD     QUEENS    21828  MERRICK BLVD
# 115993       SOUTHERN GIRLS SOUL FOOD     QUEENS    21828  MERRICK BLVD
# 154175       SOUTHERN GIRLS SOUL FOOD     QUEENS    21828  MERRICK BLVD
# 154176       SOUTHERN GIRLS SOUL FOOD     QUEENS    21828  MERRICK BLVD
# 154177       SOUTHERN GIRLS SOUL FOOD     QUEENS    21828  MERRICK BLVD
# 154178       SOUTHERN GIRLS SOUL FOOD     QUEENS    21828  MERRICK BLVD
# 173073       SOUTHERN GIRLS SOUL FOOD     QUEENS    21828  MERRICK BLVD
# 173074       SOUTHERN GIRLS SOUL FOOD     QUEENS    21828  MERRICK BLVD
# 173075       SOUTHERN GIRLS SOUL FOOD     QUEENS    21828  MERRICK BLVD
# 173076       SOUTHERN GIRLS SOUL FOOD     QUEENS    21828  MERRICK BLVD
# 173077       SOUTHERN GIRLS SOUL FOOD     QUEENS    21828  MERRICK BLVD
# 210101                   EMMY SQUARED   BROOKLYN      364      GRAND ST
# 210102                   EMMY SQUARED   BROOKLYN      364      GRAND ST
# 210103                   EMMY SQUARED   BROOKLYN      364      GRAND ST
# 210104                   EMMY SQUARED   BROOKLYN      364      GRAND ST
# 210105                   EMMY SQUARED   BROOKLYN      364      GRAND ST
# 210106                   EMMY SQUARED   BROOKLYN      364      GRAND ST
# 210107                   EMMY SQUARED   BROOKLYN      364      GRAND ST
# 210108                   EMMY SQUARED   BROOKLYN      364      GRAND ST
# 210109                   EMMY SQUARED   BROOKLYN      364      GRAND ST
# ...                               ...        ...      ...           ...
# 263571                   EMMY SQUARED   BROOKLYN      364      GRAND ST
# 263572                   EMMY SQUARED   BROOKLYN      364      GRAND ST
# 263573                   EMMY SQUARED   BROOKLYN      364      GRAND ST
# 263574                   EMMY SQUARED   BROOKLYN      364      GRAND ST
# 263575                   EMMY SQUARED   BROOKLYN      364      GRAND ST
# 263576                   EMMY SQUARED   BROOKLYN      364      GRAND ST
# 263615       SOUTHERN GIRLS SOUL FOOD     QUEENS    21828  MERRICK BLVD
# 263616       SOUTHERN GIRLS SOUL FOOD     QUEENS    21828  MERRICK BLVD
# 263617       SOUTHERN GIRLS SOUL FOOD     QUEENS    21828  MERRICK BLVD
# 263618       SOUTHERN GIRLS SOUL FOOD     QUEENS    21828  MERRICK BLVD
# 263619       SOUTHERN GIRLS SOUL FOOD     QUEENS    21828  MERRICK BLVD
# 263620       SOUTHERN GIRLS SOUL FOOD     QUEENS    21828  MERRICK BLVD
# 263621       SOUTHERN GIRLS SOUL FOOD     QUEENS    21828  MERRICK BLVD
# 263622       SOUTHERN GIRLS SOUL FOOD     QUEENS    21828  MERRICK BLVD
# 263623       SOUTHERN GIRLS SOUL FOOD     QUEENS    21828  MERRICK BLVD
# 263624       SOUTHERN GIRLS SOUL FOOD     QUEENS    21828  MERRICK BLVD
# 263647                          LUCKY  MANHATTAN      168      AVENUE B
# 263648                          LUCKY  MANHATTAN      168      AVENUE B
# 263649                          LUCKY  MANHATTAN      168      AVENUE B
# 263687  TOBY-S ESTATE COFFEE BUSHWICK   BROOKLYN        8    WILSON AVE
# 263688  TOBY-S ESTATE COFFEE BUSHWICK   BROOKLYN        8    WILSON AVE
# 263689  TOBY-S ESTATE COFFEE BUSHWICK   BROOKLYN        8    WILSON AVE
# 263690  TOBY-S ESTATE COFFEE BUSHWICK   BROOKLYN        8    WILSON AVE
# 263713                   GOURMET PARK  MANHATTAN      119     E 60TH ST
# 263714                   GOURMET PARK  MANHATTAN      119     E 60TH ST
# 263715                   GOURMET PARK  MANHATTAN      119     E 60TH ST
# 263716                   GOURMET PARK  MANHATTAN      119     E 60TH ST
# 263717                   GOURMET PARK  MANHATTAN      119     E 60TH ST
# 263718                   GOURMET PARK  MANHATTAN      119     E 60TH ST
# 263719                   GOURMET PARK  MANHATTAN      119     E 60TH ST
#
#              PHONE CUISINE DESCRIPTION INSPECTION DATE  \
# 59331   7183604535               Pizza      2017-12-09
# 59332   7183604535               Pizza      2017-12-09
# 113195  7189490400           Soul Food      2018-05-01
# 113196  7189490400           Soul Food      2018-05-01
# 113197  7189490400           Soul Food      2018-05-01
# 113198  7189490400           Soul Food      2018-05-01
# 113199  7189490400           Soul Food      2018-05-01
# 113200  7189490400           Soul Food      2018-05-01
# 113201  7189490400           Soul Food      2018-05-01
# 115991  7189490400           Soul Food      2018-05-08
# 115992  7189490400           Soul Food      2018-05-08
# 115993  7189490400           Soul Food      2018-05-08
# 154175  7189490400           Soul Food      2018-08-16
# 154176  7189490400           Soul Food      2018-08-16
# 154177  7189490400           Soul Food      2018-08-16
# 154178  7189490400           Soul Food      2018-08-16
# 173073  7189490400           Soul Food      2018-10-04
# 173074  7189490400           Soul Food      2018-10-04
# 173075  7189490400           Soul Food      2018-10-04
# 173076  7189490400           Soul Food      2018-10-04
# 173077  7189490400           Soul Food      2018-10-04
# 210101  7183604535               Pizza      2019-01-12
# 210102  7183604535               Pizza      2019-01-12
# 210103  7183604535               Pizza      2019-01-12
# 210104  7183604535               Pizza      2019-01-12
# 210105  7183604535               Pizza      2019-01-12
# 210106  7183604535               Pizza      2019-01-12
# 210107  7183604535               Pizza      2019-01-12
# 210108  7183604535               Pizza      2019-01-12
# 210109  7183604535               Pizza      2019-01-12
# ...            ...                 ...             ...
# 263571  7183604535               Pizza      2019-05-02
# 263572  7183604535               Pizza      2019-05-02
# 263573  7183604535               Pizza      2019-05-02
# 263574  7183604535               Pizza      2019-05-02
# 263575  7183604535               Pizza      2019-05-02
# 263576  7183604535               Pizza      2019-05-02
# 263615  7189490400           Soul Food      2019-05-02
# 263616  7189490400           Soul Food      2019-05-02
# 263617  7189490400           Soul Food      2019-05-02
# 263618  7189490400           Soul Food      2019-05-02
# 263619  7189490400           Soul Food      2019-05-02
# 263620  7189490400           Soul Food      2019-05-02
# 263621  7189490400           Soul Food      2019-05-02
# 263622  7189490400           Soul Food      2019-05-02
# 263623  7189490400           Soul Food      2019-05-02
# 263624  7189490400           Soul Food      2019-05-02
# 263647  2127773111               Other      2019-05-02
# 263648  2127773111               Other      2019-05-02
# 263649  2127773111               Other      2019-05-02
# 263687  3474258815    CafÃ©/Coffee/Tea      2019-05-02
# 263688  3474258815    CafÃ©/Coffee/Tea      2019-05-02
# 263689  3474258815    CafÃ©/Coffee/Tea      2019-05-02
# 263690  3474258815    CafÃ©/Coffee/Tea      2019-05-02
# 263713  2129358500               Other      2019-05-02
# 263714  2129358500               Other      2019-05-02
# 263715  2129358500               Other      2019-05-02
# 263716  2129358500               Other      2019-05-02
# 263717  2129358500               Other      2019-05-02
# 263718  2129358500               Other      2019-05-02
# 263719  2129358500               Other      2019-05-02
#
#                                                    ACTION  \
# 59331     Violations were cited in the following area(s).
# 59332     Violations were cited in the following area(s).
# 113195    Violations were cited in the following area(s).
# 113196    Violations were cited in the following area(s).
# 113197    Violations were cited in the following area(s).
# 113198    Violations were cited in the following area(s).
# 113199    Violations were cited in the following area(s).
# 113200    Violations were cited in the following area(s).
# 113201    Violations were cited in the following area(s).
# 115991    Violations were cited in the following area(s).
# 115992    Violations were cited in the following area(s).
# 115993    Violations were cited in the following area(s).
# 154175    Violations were cited in the following area(s).
# 154176    Violations were cited in the following area(s).
# 154177    Violations were cited in the following area(s).
# 154178    Violations were cited in the following area(s).
# 173073    Violations were cited in the following area(s).
# 173074    Violations were cited in the following area(s).
# 173075    Violations were cited in the following area(s).
# 173076    Violations were cited in the following area(s).
# 173077    Violations were cited in the following area(s).
# 210101    Violations were cited in the following area(s).
# 210102    Violations were cited in the following area(s).
# 210103    Violations were cited in the following area(s).
# 210104    Violations were cited in the following area(s).
# 210105    Violations were cited in the following area(s).
# 210106    Violations were cited in the following area(s).
# 210107    Violations were cited in the following area(s).
# 210108    Violations were cited in the following area(s).
# 210109    Violations were cited in the following area(s).
# ...                                                   ...
# 263571    Violations were cited in the following area(s).
# 263572    Violations were cited in the following area(s).
# 263573    Violations were cited in the following area(s).
# 263574    Violations were cited in the following area(s).
# 263575    Violations were cited in the following area(s).
# 263576    Violations were cited in the following area(s).
# 263615  Establishment Closed by DOHMH.  Violations wer...
# 263616  Establishment Closed by DOHMH.  Violations wer...
# 263617  Establishment Closed by DOHMH.  Violations wer...
# 263618  Establishment Closed by DOHMH.  Violations wer...
# 263619  Establishment Closed by DOHMH.  Violations wer...
# 263620  Establishment Closed by DOHMH.  Violations wer...
# 263621  Establishment Closed by DOHMH.  Violations wer...
# 263622  Establishment Closed by DOHMH.  Violations wer...
# 263623  Establishment Closed by DOHMH.  Violations wer...
# 263624    Violations were cited in the following area(s).
# 263647    Violations were cited in the following area(s).
# 263648    Violations were cited in the following area(s).
# 263649    Violations were cited in the following area(s).
# 263687    Violations were cited in the following area(s).
# 263688    Violations were cited in the following area(s).
# 263689    Violations were cited in the following area(s).
# 263690    Violations were cited in the following area(s).
# 263713    Violations were cited in the following area(s).
# 263714    Violations were cited in the following area(s).
# 263715    Violations were cited in the following area(s).
# 263716    Violations were cited in the following area(s).
# 263717    Violations were cited in the following area(s).
# 263718    Violations were cited in the following area(s).
# 263719    Violations were cited in the following area(s).
#
#                                     VIOLATION DESCRIPTION  SCORE  \
# 59331   Wiping cloths soiled or not stored in sanitizi...      7
# 59332   Canned food product observed dented and not se...      7
# 113195  Food Protection Certificate not held by superv...     58
# 113196  Evidence of mice or live mice present in facil...     58
# 113197  No facilities available to wash, rinse and san...     58
# 113198  Food not protected from potential source of co...     58
# 113199  Facility not vermin proof. Harborage or condit...     58
# 113200  Pesticide use not in accordance with label or ...     58
# 113201  ''''Wash hands sign not posted at hand wash f...     58
# 115991  Evidence of mice or live mice present in facil...     16
# 115992  Facility not vermin proof. Harborage or condit...     16
# 115993  Non-food contact surface improperly constructe...     16
# 154175  Filth flies or food/refuse/sewage-associated (...     22
# 154176  Food not protected from potential source of co...     22
# 154177  Food contact surface not properly washed, rins...     22
# 154178  Facility not vermin proof. Harborage or condit...     22
# 173073        Hot food item not held at or above 140Âº F.     27
# 173074  Filth flies or food/refuse/sewage-associated (...     27
# 173075  Personal cleanliness inadequate. Outer garment...     27
# 173076  Facility not vermin proof. Harborage or condit...     27
# 173077  ''''Wash hands sign not posted at hand wash f...     27
# 210101  Cold food item held above 41Âº F (smoked fish ...     47
# 210102  Food worker does not use proper utensil to eli...     47
# 210103  Evidence of mice or live mice present in facil...     47
# 210104  Hand washing facility not provided in or near ...     47
# 210105  Wiping cloths soiled or not stored in sanitizi...     47
# 210106  Facility not vermin proof. Harborage or condit...     47
# 210107  Canned food product observed dented and not se...     47
# 210108      Food contact surface not properly maintained.     47
# 210109  Single service item reused, improperly stored,...     47
# ...                                                   ...    ...
# 263571  Cold food item held above 41Âº F (smoked fish ...     51
# 263572  Evidence of mice or live mice present in facil...     51
# 263573  Food contact surface not properly washed, rins...     51
# 263574  Facility not vermin proof. Harborage or condit...     51
# 263575  Plumbing not properly installed or maintained;...     51
# 263576  Non-food contact surface improperly constructe...     51
# 263615        Hot food item not held at or above 140Âº F.    119
# 263616  Evidence of mice or live mice present in facil...    119
# 263617  Hand washing facility not provided in or near ...    119
# 263618  Insufficient or no refrigerated or hot holding...    119
# 263619  No facilities available to wash, rinse and san...    119
# 263620  Personal cleanliness inadequate. Outer garment...    119
# 263621  Food not protected from potential source of co...    119
# 263622  Wiping cloths soiled or not stored in sanitizi...    119
# 263623  Facility not vermin proof. Harborage or condit...    119
# 263624  Nuisance created or allowed to exist. Facility...      0
# 263647  Food contact surface improperly constructed or...     39
# 263648  Food not protected from potential source of co...     39
# 263649  Plumbing not properly installed or maintained;...     39
# 263687  Food contact surface improperly constructed or...     40
# 263688  Food not protected from potential source of co...     40
# 263689  Plumbing not properly installed or maintained;...     40
# 263690  Non-food contact surface improperly constructe...     40
# 263713  Food from unapproved or unknown source or home...     43
# 263714  Evidence of mice or live mice present in facil...     43
# 263715  Food not protected from potential source of co...     43
# 263716  Food contact surface not properly washed, rins...     43
# 263717  Facility not vermin proof. Harborage or condit...     43
# 263718  Plumbing not properly installed or maintained;...     43
# 263719  Non-food contact surface improperly constructe...     43
#
#                  GRADE
# 59331                A
# 59332                A
# 113195             NaN
# 113196             NaN
# 113197             NaN
# 113198             NaN
# 113199             NaN
# 113200             NaN
# 113201             NaN
# 115991             NaN
# 115992             NaN
# 115993             NaN
# 154175             NaN
# 154176             NaN
# 154177             NaN
# 154178             NaN
# 173073             NaN
# 173074             NaN
# 173075             NaN
# 173076             NaN
# 173077             NaN
# 210101             NaN
# 210102             NaN
# 210103             NaN
# 210104             NaN
# 210105             NaN
# 210106             NaN
# 210107             NaN
# 210108             NaN
# 210109             NaN
# ...                ...
# 263571               Z
# 263572               Z
# 263573               Z
# 263574               Z
# 263575               Z
# 263576               Z
# 263615  Not Yet Graded
# 263616  Not Yet Graded
# 263617  Not Yet Graded
# 263618  Not Yet Graded
# 263619  Not Yet Graded
# 263620  Not Yet Graded
# 263621  Not Yet Graded
# 263622  Not Yet Graded
# 263623  Not Yet Graded
# 263624             NaN
# 263647               Z
# 263648               Z
# 263649               Z
# 263687               Z
# 263688               Z
# 263689               Z
# 263690               Z
# 263713               Z
# 263714               Z
# 263715               Z
# 263716               Z
# 263717               Z
# 263718               Z
# 263719               Z
#
# [83 rows x 11 columns]

# %%
#extracting the year from 'INSPECTINO DATE' column
df2_worst['INSPECTION DATE'] = df2_worst['INSPECTION DATE'].map(lambda x: x.year)
# Out:
# C:\Users\Minyeong\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#creating a line chart to visualize the trend
plt.figure(figsize=(15,12))
sns.pointplot(x='INSPECTION DATE', y='SCORE', hue='RESTAURANT', data=df2_worst);

# %% [markdown]
# Based on above line chart, SOUTHEN GIRLS SOUL FOOD, EMMY SQUARED have been getting worse in terms of compliance with the food safety regulations over time, and the other three restaurants such as GOURMET PARK, TOBY-S ESTATE COFFEE BUSHWICK, LUCKY have not been inspected in 2017 and 2018, and their inspection results in 2019 indicated they were not compliant with the food safety regulations. We should not go to these "worst" restaurants for our own safety/health reasons.

# %% [markdown]
# ### Phase 6: Assess the star ratings and  reviews from Yelp for the best and the worst restaurants, respectively.

# %% [markdown]
# ### The best restaurant's ratings, review_counts, and coordinates

# %%
#importing necessary libraries
import requests
import json

# %%
#api-endpoint
api_key = '4ZV6k_jsCYOmslVsz-SDQgRCYsOngFjXx6vbdY-09nDR6UsSEDjVXu-wgDCJDnVSAVTjYBr1PZFsm00JOFfYRzaavn_ObxoflOlWJCO3SON5Z1q5lIgZXx_REEawXHYx'
headers = {'Authorization': 'Bearer %s' % api_key}

# %%
#using phone number to request CROWN FRIED CHICKEN (one of the best) restaurant from Yelp (other best restaurants unavailable)
url1='https://api.yelp.com/v3/businesses/search/phone'
params1 = {'phone':'+13474058729'}
req1 = requests.get(url1, params=params1, headers=headers)
data1 = req1.json()
data1
# Out:
# {'businesses': [{'id': 'Rl7CGxslRTQ1hF5GfvYXNw',
#    'alias': 'crown-fried-chicken-brooklyn-69',
#    'name': 'Crown Fried Chicken',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/R7tXnW-yw6u-IQnCYFQLbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/crown-fried-chicken-brooklyn-69?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_phone_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#    'review_count': 4,
#    'categories': [{'alias': 'chicken_wings', 'title': 'Chicken Wings'},
#     {'alias': 'hotdogs', 'title': 'Fast Food'}],
#    'rating': 1.5,
#    'coordinates': {'latitude': 40.669204, 'longitude': -73.897651},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '577 Sutter Ave',
#     'address2': None,
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11207',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['577 Sutter Ave', 'Brooklyn, NY 11207']},
#    'phone': '+13474058729',
#    'display_phone': '(347) 405-8729'}],
#  'total': 1}

# %%
#extracting the values(elements) in the 'businesses' key from data1 dict.
data1 = data1['businesses']
data1
# Out:
# [{'id': 'Rl7CGxslRTQ1hF5GfvYXNw',
#   'alias': 'crown-fried-chicken-brooklyn-69',
#   'name': 'Crown Fried Chicken',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/R7tXnW-yw6u-IQnCYFQLbg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/crown-fried-chicken-brooklyn-69?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_phone_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#   'review_count': 4,
#   'categories': [{'alias': 'chicken_wings', 'title': 'Chicken Wings'},
#    {'alias': 'hotdogs', 'title': 'Fast Food'}],
#   'rating': 1.5,
#   'coordinates': {'latitude': 40.669204, 'longitude': -73.897651},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '577 Sutter Ave',
#    'address2': None,
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11207',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['577 Sutter Ave', 'Brooklyn, NY 11207']},
#   'phone': '+13474058729',
#   'display_phone': '(347) 405-8729'}]

# %%
#converting data1 to pandas DataFrame.
data1_df = pd.DataFrame(data1)
data1_df
# Out:
#                              alias  \
# 0  crown-fried-chicken-brooklyn-69
#
#                                           categories  \
# 0  [{'alias': 'chicken_wings', 'title': 'Chicken ...
#
#                                         coordinates   display_phone  \
# 0  {'latitude': 40.669204, 'longitude': -73.897651}  (347) 405-8729
#
#                        id                                          image_url  \
# 0  Rl7CGxslRTQ1hF5GfvYXNw  https://s3-media3.fl.yelpcdn.com/bphoto/R7tXnW...
#
#    is_closed                                           location  \
# 0      False  {'address1': '577 Sutter Ave', 'address2': Non...
#
#                   name         phone  rating  review_count  \
# 0  Crown Fried Chicken  +13474058729     1.5             4
#
#          transactions                                                url
# 0  [pickup, delivery]  https://www.yelp.com/biz/crown-fried-chicken-b...

# %%
#separating the coordinates into latitude and longitude
best_loc = data1_df['coordinates'].apply(pd.Series)
best_loc
# Out:
#     latitude  longitude
# 0  40.669204 -73.897651

# %% [markdown]
# Based on data1_df, CROWN FRIED CHICKEN has star rating of 1.5 and the review_count is only 4 according to Yelp, even though the restaurant inspection result describes this restaurant as one of the top 5 in terms of compliance with the food safety regulations. I will further investigate the review comments on Yelp in the later steps.
# <br>
# Also, above table best_loc shows the latitude and the longitude of one of the best restaurant, CROWN FRIED CHICKEN. I will plot it on the map after I obtain the latitude and the longitude of the worst restaurant, SOUTHERN GIRLS SOUL FOOD.

# %% [markdown]
# ### The worst restaurant's ratings, review_counts, and coordinates

# %%
#using phone number to request SOUTHERN GIRLS SOUL FOOD (the worst) restaurant from Yelp
url2='https://api.yelp.com/v3/businesses/search/phone'
params2 = {'phone':'+17189490400'}
req2 = requests.get(url2, params=params2, headers=headers)
data2 = req2.json()
data2
# Out:
# {'businesses': [{'id': 'EaXnHlHPntg7of31PlfWgA',
#    'alias': 'southern-girls-soul-food-laurelton',
#    'name': 'Southern Girls Soul Food',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/43M6I9Tfi7l7yZmSrA4u8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/southern-girls-soul-food-laurelton?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_phone_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#    'review_count': 73,
#    'categories': [{'alias': 'southern', 'title': 'Southern'},
#     {'alias': 'soulfood', 'title': 'Soul Food'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 40.6793539, 'longitude': -73.7509401},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '218-28 Merrick Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Laurelton',
#     'zip_code': '11413',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['218-28 Merrick Blvd', 'Laurelton, NY 11413']},
#    'phone': '+17189490400',
#    'display_phone': '(718) 949-0400'}],
#  'total': 1}

# %%
#extracting the values(elements) in the 'businesses' key from data2 dict.
data2 = data2['businesses']
data2
# Out:
# [{'id': 'EaXnHlHPntg7of31PlfWgA',
#   'alias': 'southern-girls-soul-food-laurelton',
#   'name': 'Southern Girls Soul Food',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/43M6I9Tfi7l7yZmSrA4u8Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/southern-girls-soul-food-laurelton?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_phone_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#   'review_count': 73,
#   'categories': [{'alias': 'southern', 'title': 'Southern'},
#    {'alias': 'soulfood', 'title': 'Soul Food'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 40.6793539, 'longitude': -73.7509401},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '218-28 Merrick Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Laurelton',
#    'zip_code': '11413',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['218-28 Merrick Blvd', 'Laurelton, NY 11413']},
#   'phone': '+17189490400',
#   'display_phone': '(718) 949-0400'}]

# %%
#converting data2 to pandas DataFrame.
data2_df = pd.DataFrame(data2)
data2_df
# Out:
#                                 alias  \
# 0  southern-girls-soul-food-laurelton
#
#                                           categories  \
# 0  [{'alias': 'southern', 'title': 'Southern'}, {...
#
#                                          coordinates   display_phone  \
# 0  {'latitude': 40.6793539, 'longitude': -73.7509...  (718) 949-0400
#
#                        id                                          image_url  \
# 0  EaXnHlHPntg7of31PlfWgA  https://s3-media1.fl.yelpcdn.com/bphoto/43M6I9...
#
#    is_closed                                           location  \
# 0      False  {'address1': '218-28 Merrick Blvd', 'address2'...
#
#                        name         phone price  rating  review_count  \
# 0  Southern Girls Soul Food  +17189490400     $     2.5            73
#
#          transactions                                                url
# 0  [delivery, pickup]  https://www.yelp.com/biz/southern-girls-soul-f...

# %%
#separating the coordinates into latitude and longitude
worst_loc = data2_df['coordinates'].apply(pd.Series)
worst_loc
# Out:
#     latitude  longitude
# 0  40.679354  -73.75094

# %% [markdown]
# Based on data2_df, SOUTHERN GIRLS SOUL FOOD has star rating of 2.5 and the review_count is 73 according to Yelp, even though the restaurant inspection result describes this restaurant as one of the worst in terms of compliance with the food safety regulations. I will further investigate the review comments on Yelp in the later steps.<br> This is surprising because the star rating of the best restaurant CROWN FRIED CHICKEN was 1.5 and the review_count was only 4 according to Yelp as described above.<br>
# The table worst_loc above shows the latitude and the longitude of one of the worst restaurant, SOUTHERN GIRLS SOUL FOOD. I will plot the best restaurant and the worst restaurant on the map as below.

# %%
#combining the two dataframes, best_loc and worst_loc into one
location_df = best_loc.append(worst_loc, ignore_index=True)
location_df
# Out:
#     latitude  longitude
# 0  40.669204 -73.897651
# 1  40.679354 -73.750940

# %%
#combining the two dataframes, data1_df and data2_df into one
data12_df = data1_df.append(data2_df, ignore_index=True)
data12_df
# Out:
# C:\Users\Minyeong\Anaconda3\lib\site-packages\pandas\core\frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
#                                 alias  \
# 0     crown-fried-chicken-brooklyn-69
# 1  southern-girls-soul-food-laurelton
#
#                                           categories  \
# 0  [{'alias': 'chicken_wings', 'title': 'Chicken ...
# 1  [{'alias': 'southern', 'title': 'Southern'}, {...
#
#                                          coordinates   display_phone  \
# 0   {'latitude': 40.669204, 'longitude': -73.897651}  (347) 405-8729
# 1  {'latitude': 40.6793539, 'longitude': -73.7509...  (718) 949-0400
#
#                        id                                          image_url  \
# 0  Rl7CGxslRTQ1hF5GfvYXNw  https://s3-media3.fl.yelpcdn.com/bphoto/R7tXnW...
# 1  EaXnHlHPntg7of31PlfWgA  https://s3-media1.fl.yelpcdn.com/bphoto/43M6I9...
#
#    is_closed                                           location  \
# 0      False  {'address1': '577 Sutter Ave', 'address2': Non...
# 1      False  {'address1': '218-28 Merrick Blvd', 'address2'...
#
#                        name         phone price  rating  review_count  \
# 0       Crown Fried Chicken  +13474058729   NaN     1.5             4
# 1  Southern Girls Soul Food  +17189490400     $     2.5            73
#
#          transactions                                                url
# 0  [pickup, delivery]  https://www.yelp.com/biz/crown-fried-chicken-b...
# 1  [delivery, pickup]  https://www.yelp.com/biz/southern-girls-soul-f...

# %%
#concatenating the two dataframes
concat_df = pd.concat([location_df, data12_df], axis=1, sort=False)
concat_df
# Out:
#     latitude  longitude                               alias  \
# 0  40.669204 -73.897651     crown-fried-chicken-brooklyn-69
# 1  40.679354 -73.750940  southern-girls-soul-food-laurelton
#
#                                           categories  \
# 0  [{'alias': 'chicken_wings', 'title': 'Chicken ...
# 1  [{'alias': 'southern', 'title': 'Southern'}, {...
#
#                                          coordinates   display_phone  \
# 0   {'latitude': 40.669204, 'longitude': -73.897651}  (347) 405-8729
# 1  {'latitude': 40.6793539, 'longitude': -73.7509...  (718) 949-0400
#
#                        id                                          image_url  \
# 0  Rl7CGxslRTQ1hF5GfvYXNw  https://s3-media3.fl.yelpcdn.com/bphoto/R7tXnW...
# 1  EaXnHlHPntg7of31PlfWgA  https://s3-media1.fl.yelpcdn.com/bphoto/43M6I9...
#
#    is_closed                                           location  \
# 0      False  {'address1': '577 Sutter Ave', 'address2': Non...
# 1      False  {'address1': '218-28 Merrick Blvd', 'address2'...
#
#                        name         phone price  rating  review_count  \
# 0       Crown Fried Chicken  +13474058729   NaN     1.5             4
# 1  Southern Girls Soul Food  +17189490400     $     2.5            73
#
#          transactions                                                url
# 0  [pickup, delivery]  https://www.yelp.com/biz/crown-fried-chicken-b...
# 1  [delivery, pickup]  https://www.yelp.com/biz/southern-girls-soul-f...

# %%
#declaring a list that is to be converted into a column 
best_worst = ['the best restaurant', 'the worst restaurant'] 
  
#using 'recommendation' as the column name and equating it to the list 
concat_df['recommendation'] = best_worst
concat_df
# Out:
#     latitude  longitude                               alias  \
# 0  40.669204 -73.897651     crown-fried-chicken-brooklyn-69
# 1  40.679354 -73.750940  southern-girls-soul-food-laurelton
#
#                                           categories  \
# 0  [{'alias': 'chicken_wings', 'title': 'Chicken ...
# 1  [{'alias': 'southern', 'title': 'Southern'}, {...
#
#                                          coordinates   display_phone  \
# 0   {'latitude': 40.669204, 'longitude': -73.897651}  (347) 405-8729
# 1  {'latitude': 40.6793539, 'longitude': -73.7509...  (718) 949-0400
#
#                        id                                          image_url  \
# 0  Rl7CGxslRTQ1hF5GfvYXNw  https://s3-media3.fl.yelpcdn.com/bphoto/R7tXnW...
# 1  EaXnHlHPntg7of31PlfWgA  https://s3-media1.fl.yelpcdn.com/bphoto/43M6I9...
#
#    is_closed                                           location  \
# 0      False  {'address1': '577 Sutter Ave', 'address2': Non...
# 1      False  {'address1': '218-28 Merrick Blvd', 'address2'...
#
#                        name         phone price  rating  review_count  \
# 0       Crown Fried Chicken  +13474058729   NaN     1.5             4
# 1  Southern Girls Soul Food  +17189490400     $     2.5            73
#
#          transactions                                                url  \
# 0  [pickup, delivery]  https://www.yelp.com/biz/crown-fried-chicken-b...
# 1  [delivery, pickup]  https://www.yelp.com/biz/southern-girls-soul-f...
#
#          recommendation
# 0   the best restaurant
# 1  the worst restaurant

# %%
#importing necessary libraries
import folium 
import pandas as pd 

#Making an empty map using New York Coordinates: 40.7128° N, 74.0060° W
m = folium.Map(location=[40.71, -74.0060], tiles="OpenStreetMap", zoom_start=11) 

#adding marker one by one on the map 
for i in range(0,len(concat_df)): 
    my_string = 'recommendation: {}, phone: {}'.format(concat_df.iloc[i]['recommendation'], concat_df.iloc[i]['phone'])
    folium.Marker([concat_df.iloc[i]['latitude'], concat_df.iloc[i]['longitude']], tooltip=concat_df.iloc[i]['name'], 
                  popup=my_string
                  ).add_to(m) 
m

# Save it as html
m.save('nyc_restaurants_map.html')

from IPython.display import HTML
HTML('<iframe src=nyc_restaurants_map.html width=700 height=450></iframe>')
# Out:
# C:\Users\Minyeong\Anaconda3\lib\site-packages\IPython\core\display.py:689: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe src=nyc_restaurants_map.html width=700 height=450></iframe>

# %% [markdown]
# On the map above, I showed the best restaurant and the worst restaurant that has popup displaying the recommendation such as "best" or "worst" and the phone number respectively, as well as the tooltip that displays the respective restaurant name.

# %% [markdown]
# ### Phase 7: Assess the review comments from Yelp for the best and the worst restaurants, respectively.

# %% [markdown]
# ### The best restaurant, CROWN FRIED CHICKEN reviews

# %%
#requesting the CROWN FRIED CHICKEN review comments from Yelp
url3 = "https://api.yelp.com/v3/businesses/Rl7CGxslRTQ1hF5GfvYXNw/reviews"
req3 = requests.get(url3, headers=headers)
data3 = req3.json()
data3
# Out:
# {'reviews': [{'id': 'XB2pCtszEvagRX_nYZp6Rw',
#    'url': 'https://www.yelp.com/biz/crown-fried-chicken-brooklyn-69?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&hrid=XB2pCtszEvagRX_nYZp6Rw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#    'text': 'This place is DISGUSTING!!! I went in with a friend and we both got burgers. In the middle of her burger she found a FLY and the worker gave a reaction like...',
#    'rating': 1,
#    'time_created': '2018-04-12 09:46:13',
#    'user': {'id': 'h_l_qNgZpDrF9h9FbCRgJA',
#     'profile_url': 'https://www.yelp.com/user_details?userid=h_l_qNgZpDrF9h9FbCRgJA',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/zA7t88ATGqV0zQmUAXfSPA/o.jpg',
#     'name': 'Sandra G.'}},
#   {'id': '2MWBRBkTgqyKja_RkKCzVw',
#    'url': 'https://www.yelp.com/biz/crown-fried-chicken-brooklyn-69?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&hrid=2MWBRBkTgqyKja_RkKCzVw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#    'text': 'There was a visible mouse trap and i found a deed fly in my cheese burger.  I showed it to the guy and he smiled. I lost my appetite and nearly threw up.',
#    'rating': 1,
#    'time_created': '2018-04-12 09:47:45',
#    'user': {'id': 'jVHQgu1bEKqxWAIUnK_zwQ',
#     'profile_url': 'https://www.yelp.com/user_details?userid=jVHQgu1bEKqxWAIUnK_zwQ',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/kZ1m9JuUWfzRCiw3-vco6A/o.jpg',
#     'name': 'Taisha C.'}},
#   {'id': 'cTU95s3C8RKdDsVdlJm1FQ',
#    'url': 'https://www.yelp.com/biz/crown-fried-chicken-brooklyn-69?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&hrid=cTU95s3C8RKdDsVdlJm1FQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#    'text': 'I live in St. Louis and someone fraudulently used my Paypal account to purchase food from here.  This person used the app YELP EAT24.  I have already filed...',
#    'rating': 1,
#    'time_created': '2017-07-28 20:36:12',
#    'user': {'id': 'oH32wToITkPy9i7Szu6xmQ',
#     'profile_url': 'https://www.yelp.com/user_details?userid=oH32wToITkPy9i7Szu6xmQ',
#     'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/doRDZOioZ-ST-Ku6Tw-J2Q/o.jpg',
#     'name': 'Steve D.'}}],
#  'total': 4,
#  'possible_languages': ['en']}

# %%
#extracting the values(elements) in the 'reviews' key from data3 dict.
data3 = data3['reviews']
data3
# Out:
# [{'id': 'XB2pCtszEvagRX_nYZp6Rw',
#   'url': 'https://www.yelp.com/biz/crown-fried-chicken-brooklyn-69?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&hrid=XB2pCtszEvagRX_nYZp6Rw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#   'text': 'This place is DISGUSTING!!! I went in with a friend and we both got burgers. In the middle of her burger she found a FLY and the worker gave a reaction like...',
#   'rating': 1,
#   'time_created': '2018-04-12 09:46:13',
#   'user': {'id': 'h_l_qNgZpDrF9h9FbCRgJA',
#    'profile_url': 'https://www.yelp.com/user_details?userid=h_l_qNgZpDrF9h9FbCRgJA',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/zA7t88ATGqV0zQmUAXfSPA/o.jpg',
#    'name': 'Sandra G.'}},
#  {'id': '2MWBRBkTgqyKja_RkKCzVw',
#   'url': 'https://www.yelp.com/biz/crown-fried-chicken-brooklyn-69?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&hrid=2MWBRBkTgqyKja_RkKCzVw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#   'text': 'There was a visible mouse trap and i found a deed fly in my cheese burger.  I showed it to the guy and he smiled. I lost my appetite and nearly threw up.',
#   'rating': 1,
#   'time_created': '2018-04-12 09:47:45',
#   'user': {'id': 'jVHQgu1bEKqxWAIUnK_zwQ',
#    'profile_url': 'https://www.yelp.com/user_details?userid=jVHQgu1bEKqxWAIUnK_zwQ',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/kZ1m9JuUWfzRCiw3-vco6A/o.jpg',
#    'name': 'Taisha C.'}},
#  {'id': 'cTU95s3C8RKdDsVdlJm1FQ',
#   'url': 'https://www.yelp.com/biz/crown-fried-chicken-brooklyn-69?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&hrid=cTU95s3C8RKdDsVdlJm1FQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#   'text': 'I live in St. Louis and someone fraudulently used my Paypal account to purchase food from here.  This person used the app YELP EAT24.  I have already filed...',
#   'rating': 1,
#   'time_created': '2017-07-28 20:36:12',
#   'user': {'id': 'oH32wToITkPy9i7Szu6xmQ',
#    'profile_url': 'https://www.yelp.com/user_details?userid=oH32wToITkPy9i7Szu6xmQ',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/doRDZOioZ-ST-Ku6Tw-J2Q/o.jpg',
#    'name': 'Steve D.'}}]

# %%
#converting data3 to pandas DataFrame.
data3_df = pd.DataFrame(data3)
data3_df
# Out:
#                        id  rating  \
# 0  XB2pCtszEvagRX_nYZp6Rw       1
# 1  2MWBRBkTgqyKja_RkKCzVw       1
# 2  cTU95s3C8RKdDsVdlJm1FQ       1
#
#                                                 text         time_created  \
# 0  This place is DISGUSTING!!! I went in with a f...  2018-04-12 09:46:13
# 1  There was a visible mouse trap and i found a d...  2018-04-12 09:47:45
# 2  I live in St. Louis and someone fraudulently u...  2017-07-28 20:36:12
#
#                                                  url  \
# 0  https://www.yelp.com/biz/crown-fried-chicken-b...
# 1  https://www.yelp.com/biz/crown-fried-chicken-b...
# 2  https://www.yelp.com/biz/crown-fried-chicken-b...
#
#                                                 user
# 0  {'id': 'h_l_qNgZpDrF9h9FbCRgJA', 'profile_url'...
# 1  {'id': 'jVHQgu1bEKqxWAIUnK_zwQ', 'profile_url'...
# 2  {'id': 'oH32wToITkPy9i7Szu6xmQ', 'profile_url'...

# %% [markdown]
# Based on the text column in above data3_df table, the reviews were not good. One of the review said this place was disgusting, and another review said there was a mouse trap and found a fly in cheese burger. However, both of these reviews were created on April 12, 2018. The restaurant inspection date that I used to assess was May 2, 2019, which means the CROWN FRIED CHICKEN restaurant made an effort to improve their compliance with the food safety regulations. This also matches with the result that I drew based on the line chart above.

# %% [markdown]
# ### The worst restaurant, SOUTHERN GIRLS SOUL FOOD reviews

# %%
#requesting the SOUTHERN GIRLS SOUL FOOD review comments from Yelp
url4 = "https://api.yelp.com/v3/businesses/EaXnHlHPntg7of31PlfWgA/reviews"
req4 = requests.get(url4, headers=headers)
data4 = req4.json()
data4
# Out:
# {'reviews': [{'id': 'DBHi0kvaIE2GGoErqYGtFg',
#    'url': 'https://www.yelp.com/biz/southern-girls-soul-food-laurelton?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&hrid=DBHi0kvaIE2GGoErqYGtFg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#    'text': 'My Hubby & I was looking for A Good Soul food Restaurant  to visit to get some of our Quality Time in & Boy Must I Say It was well worth our drive!!..First...',
#    'rating': 4,
#    'time_created': '2019-04-28 10:01:56',
#    'user': {'id': 'zLYctGPlnRh1eCQHuxWnpA',
#     'profile_url': 'https://www.yelp.com/user_details?userid=zLYctGPlnRh1eCQHuxWnpA',
#     'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/Zy74RRA9V2g35dAiT-rRiQ/o.jpg',
#     'name': 'Janise S.'}},
#   {'id': 'irysLaIaZCpePNRmjD0SmQ',
#    'url': 'https://www.yelp.com/biz/southern-girls-soul-food-laurelton?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&hrid=irysLaIaZCpePNRmjD0SmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#    'text': "First off I wanted to start this off by saying I really liked this place when it was across the street!!! I'm gonna state nice things before I go innnn on...",
#    'rating': 1,
#    'time_created': '2019-04-13 12:50:26',
#    'user': {'id': '4XYCFtg1x41XcPqfPZEdUw',
#     'profile_url': 'https://www.yelp.com/user_details?userid=4XYCFtg1x41XcPqfPZEdUw',
#     'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/DicEmbRXFR4SLGZawEg9WA/o.jpg',
#     'name': 'Nivea B.'}},
#   {'id': 'Sid8xnToDZVEzlSBGR6LDw',
#    'url': 'https://www.yelp.com/biz/southern-girls-soul-food-laurelton?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&hrid=Sid8xnToDZVEzlSBGR6LDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#    'text': 'If I could give 0 stars I would !!!! DO NOT EAT THERE !! I ordered their fried bbq chicken with Mac and cheese & candied yams & the Mac and cheese tasted...',
#    'rating': 1,
#    'time_created': '2019-05-05 12:34:11',
#    'user': {'id': 'rALabD_2d3P9zdNy1fGsPw',
#     'profile_url': 'https://www.yelp.com/user_details?userid=rALabD_2d3P9zdNy1fGsPw',
#     'image_url': None,
#     'name': 'Amani E.'}}],
#  'total': 73,
#  'possible_languages': ['en']}

# %%
#extracting the values(elements) in the 'reviews' key from data4 dict.
data4 = data4['reviews']
data4
# Out:
# [{'id': 'DBHi0kvaIE2GGoErqYGtFg',
#   'url': 'https://www.yelp.com/biz/southern-girls-soul-food-laurelton?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&hrid=DBHi0kvaIE2GGoErqYGtFg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#   'text': 'My Hubby & I was looking for A Good Soul food Restaurant  to visit to get some of our Quality Time in & Boy Must I Say It was well worth our drive!!..First...',
#   'rating': 4,
#   'time_created': '2019-04-28 10:01:56',
#   'user': {'id': 'zLYctGPlnRh1eCQHuxWnpA',
#    'profile_url': 'https://www.yelp.com/user_details?userid=zLYctGPlnRh1eCQHuxWnpA',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/photo/Zy74RRA9V2g35dAiT-rRiQ/o.jpg',
#    'name': 'Janise S.'}},
#  {'id': 'irysLaIaZCpePNRmjD0SmQ',
#   'url': 'https://www.yelp.com/biz/southern-girls-soul-food-laurelton?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&hrid=irysLaIaZCpePNRmjD0SmQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#   'text': "First off I wanted to start this off by saying I really liked this place when it was across the street!!! I'm gonna state nice things before I go innnn on...",
#   'rating': 1,
#   'time_created': '2019-04-13 12:50:26',
#   'user': {'id': '4XYCFtg1x41XcPqfPZEdUw',
#    'profile_url': 'https://www.yelp.com/user_details?userid=4XYCFtg1x41XcPqfPZEdUw',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/photo/DicEmbRXFR4SLGZawEg9WA/o.jpg',
#    'name': 'Nivea B.'}},
#  {'id': 'Sid8xnToDZVEzlSBGR6LDw',
#   'url': 'https://www.yelp.com/biz/southern-girls-soul-food-laurelton?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&hrid=Sid8xnToDZVEzlSBGR6LDw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#   'text': 'If I could give 0 stars I would !!!! DO NOT EAT THERE !! I ordered their fried bbq chicken with Mac and cheese & candied yams & the Mac and cheese tasted...',
#   'rating': 1,
#   'time_created': '2019-05-05 12:34:11',
#   'user': {'id': 'rALabD_2d3P9zdNy1fGsPw',
#    'profile_url': 'https://www.yelp.com/user_details?userid=rALabD_2d3P9zdNy1fGsPw',
#    'image_url': None,
#    'name': 'Amani E.'}}]

# %%
#converting data4 to pandas DataFrame.
data4_df = pd.DataFrame(data4)
data4_df
# Out:
#                        id  rating  \
# 0  DBHi0kvaIE2GGoErqYGtFg       4
# 1  irysLaIaZCpePNRmjD0SmQ       1
# 2  Sid8xnToDZVEzlSBGR6LDw       1
#
#                                                 text         time_created  \
# 0  My Hubby & I was looking for A Good Soul food ...  2019-04-28 10:01:56
# 1  First off I wanted to start this off by saying...  2019-04-13 12:50:26
# 2  If I could give 0 stars I would !!!! DO NOT EA...  2019-05-05 12:34:11
#
#                                                  url  \
# 0  https://www.yelp.com/biz/southern-girls-soul-f...
# 1  https://www.yelp.com/biz/southern-girls-soul-f...
# 2  https://www.yelp.com/biz/southern-girls-soul-f...
#
#                                                 user
# 0  {'id': 'zLYctGPlnRh1eCQHuxWnpA', 'profile_url'...
# 1  {'id': '4XYCFtg1x41XcPqfPZEdUw', 'profile_url'...
# 2  {'id': 'rALabD_2d3P9zdNy1fGsPw', 'profile_url'...

# %% [markdown]
# Based on the text column in above data4_df table, the reviews are not consistent. One review that gave 4 star rating said it was well worth the drive to get some quality time and good soul food. However, the other two reviews gave 1 star ratings, respectively, and one review said the reviewer was going to state nice things before going into the restaurant, and another review said if he/she could give 0 star he/she would, because of the taste of food.
# These reviews were all posted in 2019, and based on the line chart above, SOUTHERN GIRLS SOUL FOOD have been getting worse since 2018. Hence, even though one of the recent reviewer said it was well worth the drive for the quality time and good soul food, I would not recommend this restauarant, as the reviewer did not say about food safety, and the restaurant inspection result showed this restaurant received the highest violation score in May 2, 2019.

# %% [markdown]
# Considering altogether, I could find that the reviews and the star ratings from Yelp do not always match with the restaurant inspection result. Some reviewers gave a high star rating because of the taste of food, not mentioning their compliance with the food safety regulations. Hence, I would suggest that we shoud take into account the restaurant inspection result before we go to the restaurant, instead of solely relying on the star ratings and reviews on the Yelp, because great taste or service or convenient distance do not guarantee the safety of food they serve.

# %% [markdown]
# ### Phase 8: Assess the inspection results of the Yelp's best restaurants in NYC

# %% [markdown]
# ### Lastly, I will assess the inspection results of the best restaurants in NYC recommended by Yelp, to see if there is discrepancy.

# %%
#importing the best restaurants in New York City from Yelp.com
params = {'term':'restaurant','location':'New York City'}
url5 = 'https://api.yelp.com/v3/businesses/search'

# %%
#sending get requst to extract New York City restaurants and saving the response as req5, response object.
req5 = requests.get(url5, params=params, headers=headers)
req5
# Out:
# <Response [200]>

# %%
#returning a dictionary containing JSON parsed into native Python objects using the response object's json method.
data5 = req5.json()
data5
# Out:
# {'businesses': [{'id': 'lMy1BYJ5HX8TccXTBwdRNg',
#    'alias': 'covenhoven-brooklyn',
#    'name': 'Covenhoven',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OZZ2U4MyoiBUrjQMZgqcRg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/covenhoven-brooklyn?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#    'review_count': 113,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.675246, 'longitude': -73.960244},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '730 Classon Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['730 Classon Ave', 'Brooklyn, NY 11238']},
#    'phone': '+17184839950',
#    'display_phone': '(718) 483-9950',
#    'distance': 4417.8365326838175},
#   {'id': 'ETgJqJHV7BW6pIr9Ox74sA',
#    'alias': 'amélie-new-york',
#    'name': 'Amélie',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cSDgVuPMnJgMLTrTNSEXug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/am%C3%A9lie-new-york?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#    'review_count': 2450,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7327, 'longitude': -73.99766},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '22 W 8th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['22 W 8th St', 'New York, NY 10011']},
#    'phone': '+12125332962',
#    'display_phone': '(212) 533-2962',
#    'distance': 3038.8699032940094},
#   {'id': 'ehUuSk5gPTCQmwS_ubgKRA',
#    'alias': 'upstate-new-york-2',
#    'name': 'Upstate',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RvnUVU7MF7DT0RzNL-EebQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/upstate-new-york-2?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#    'review_count': 1705,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7263139141197,
#     'longitude': -73.9864901976935},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '95 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['95 1st Ave', 'New York, NY 10003']},
#    'phone': '+16467915400',
#    'display_phone': '(646) 791-5400',
#    'distance': 2411.9187177986864},
#   {'id': 'CwOAKJdX8AMz5iAoA-ZEuA',
#    'alias': 'uglyduckling-brooklyn',
#    'name': 'Uglyduckling',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zo96XEmO2i-KtBs0_5pQyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/uglyduckling-brooklyn?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#    'review_count': 437,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.686023, 'longitude': -73.991302},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '166 Smith St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['166 Smith St', 'Brooklyn, NY 11201']},
#    'phone': '+17184513825',
#    'display_phone': '(718) 451-3825',
#    'distance': 2174.2838817065267},
#   {'id': 'jjJc_CrkB2HodEinB6cWww',
#    'alias': 'lovemama-new-york',
#    'name': 'LoveMama',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bLlFKTlVuLfmF-lIDGIjZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lovemama-new-york?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#    'review_count': 4178,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'malaysian', 'title': 'Malaysian'},
#     {'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7303859, 'longitude': -73.9860613},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '174 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['174 2nd Ave', 'New York, NY 10003']},
#    'phone': '+12122545370',
#    'display_phone': '(212) 254-5370',
#    'distance': 2858.7729410008346},
#   {'id': 'I2lgw_7DUnwD92ND4PN-Ow',
#    'alias': 'aunt-jakes-new-york',
#    'name': "Aunt Jake's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hMhn_lnES3QWc4Gtihvr0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aunt-jakes-new-york?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#    'review_count': 1163,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'pastashops', 'title': 'Pasta Shops'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7190315, 'longitude': -73.9977161},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '149 Mulberry St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['149 Mulberry St', 'New York, NY 10013']},
#    'phone': '+16468580470',
#    'display_phone': '(646) 858-0470',
#    'distance': 1538.0627375870665},
#   {'id': 'UA2M9QFZghe-9th2KwLoWQ',
#    'alias': 'burger-and-lobster-new-york-4',
#    'name': 'Burger & Lobster',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1rHd7F4zztAsScwzM0vDmw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/burger-and-lobster-new-york-4?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#    'review_count': 5053,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74007, 'longitude': -73.99344},
#    'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '39 W 19th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['39 W 19th St', 'New York, NY 10011']},
#    'phone': '+16468337532',
#    'display_phone': '(646) 833-7532',
#    'distance': 3852.2188529432046},
#   {'id': 'C2o3Iw-DXjoUJFgQIbiqkQ',
#    'alias': 'bocaphê-new-york-3',
#    'name': 'BoCaphe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ck7z-CGvku5kJDPyRkIfew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bocaph%C3%AA-new-york-3?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#    'review_count': 1113,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.722046, 'longitude': -73.997557},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '222 Lafayette St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['222 Lafayette St', 'New York, NY 10012']},
#    'phone': '+16468821939',
#    'display_phone': '(646) 882-1939',
#    'distance': 1866.3436634084576},
#   {'id': 's3jou_L_LVYGkNHiuhjlew',
#    'alias': 'boucherie-west-village-new-york-3',
#    'name': 'Boucherie West Village',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-5TXMVrjARsqKQHDg-hKbQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boucherie-west-village-new-york-3?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#    'review_count': 1020,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.733063, 'longitude': -74.0028772},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$$',
#    'location': {'address1': '99 7th Ave S',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['99 7th Ave S', 'New York, NY 10014']},
#    'phone': '+12128371616',
#    'display_phone': '(212) 837-1616',
#    'distance': 3155.0505772747442},
#   {'id': 'hmdm-dO72hLsMQwQRcGEUQ',
#    'alias': 'atrium-dumbo-brooklyn',
#    'name': 'Atrium Dumbo',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TAog5s7slOJ0778OGRzuWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/atrium-dumbo-brooklyn?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#    'review_count': 597,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'french', 'title': 'French'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7033899, 'longitude': -73.9904923},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '15 Main St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['15 Main St', 'Brooklyn, NY 11201']},
#    'phone': '+17188581095',
#    'display_phone': '(718) 858-1095',
#    'distance': 392.6441573431464},
#   {'id': 'xt4sa64WOrpJvZBDPNPNYg',
#    'alias': 'jacobs-pickles-new-york',
#    'name': "Jacob's Pickles",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/167Rl2s1oMge_2ZSDD1z0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jacobs-pickles-new-york?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#    'review_count': 3674,
#    'categories': [{'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'southern', 'title': 'Southern'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7866504411994,
#     'longitude': -73.9755284786224},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '509 Amsterdam Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['509 Amsterdam Ave', 'New York, NY 10024']},
#    'phone': '+12124705566',
#    'display_phone': '(212) 470-5566',
#    'distance': 9166.964737863183},
#   {'id': 'ysqgdbSrezXgVwER2kQWKA',
#    'alias': 'julianas-pizza-brooklyn-5',
#    'name': "Juliana's Pizza",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7JtwTxhWHf3YS70Ss_CfxA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/julianas-pizza-brooklyn-5?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#    'review_count': 1950,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7026153030093,
#     'longitude': -73.9934159993549},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '19 Old Fulton St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['19 Old Fulton St', 'Brooklyn, NY 11201']},
#    'phone': '+17185966700',
#    'display_phone': '(718) 596-6700',
#    'distance': 323.20506308227306},
#   {'id': 'Me4TxTbPPQZQopW1wOGx5g',
#    'alias': 'jacks-wife-freda-new-york',
#    'name': "Jack's Wife Freda",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TRJ5LNNH7UAybD4TlCCf2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jacks-wife-freda-new-york?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#    'review_count': 1738,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72213, 'longitude': -73.99756},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '224 Lafayette St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['224 Lafayette St', 'New York, NY 10012']},
#    'phone': '+12125108550',
#    'display_phone': '(212) 510-8550',
#    'distance': 1874.7368920314377},
#   {'id': 'qCrM1gDsY7bc3Tk61VBIBQ',
#    'alias': 'savida-new-york',
#    'name': 'Savida',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/oOk9vD2imIqAdGTWgduJeQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/savida-new-york?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#    'review_count': 27,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71645, 'longitude': -74.00783},
#    'transactions': ['restaurant_reservation'],
#    'location': {'address1': '139 Duane St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['139 Duane St', 'New York, NY 10013']},
#    'phone': '+12122023175',
#    'display_phone': '(212) 202-3175',
#    'distance': 1671.1005153773624},
#   {'id': '4aF0F8w7yXX9o5_QFky_ig',
#    'alias': 'celestine-brooklyn',
#    'name': 'Celestine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Qioy61vucqa3heDewB8btg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/celestine-brooklyn?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#    'review_count': 154,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.704676, 'longitude': -73.987975},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1 John St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1 John St', 'Brooklyn, NY 11201']},
#    'phone': '+17185225356',
#    'display_phone': '(718) 522-5356',
#    'distance': 539.4069533813018},
#   {'id': '0CjK3esfpFcxIopebzjFxA',
#    'alias': 'joes-shanghai-new-york-2',
#    'name': "Joe's Shanghai",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ekUo5egd4dlE7zJyb4-Leg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joes-shanghai-new-york-2?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#    'review_count': 5704,
#    'categories': [{'alias': 'shanghainese', 'title': 'Shanghainese'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7146691442891,
#     'longitude': -73.9977602206654},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '9 Pell St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['9 Pell St', 'New York, NY 10013']},
#    'phone': '+12122338888',
#    'display_phone': '(212) 233-8888',
#    'distance': 1066.5085498349097},
#   {'id': 'qOomR3AwClOGpV1HdqOTFg',
#    'alias': 'les-enfants-de-boheme-new-york',
#    'name': 'Les Enfants de Boheme',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/I1V4kucJO69x8L8UhDwiiA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/les-enfants-de-boheme-new-york?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#    'review_count': 198,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7136187, 'longitude': -73.9888503},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '177 Henry St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['177 Henry St', 'New York, NY 10002']},
#    'phone': '+16464764843',
#    'display_phone': '(646) 476-4843',
#    'distance': 1026.2110364656392},
#   {'id': 'xZ96vaoL-cQjfotmUKtjJQ',
#    'alias': 'barn-joo-35-new-york',
#    'name': 'Barn Joo 35',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1R5CgYlK5qGUhKZOvZThKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barn-joo-35-new-york?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#    'review_count': 1415,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74964, 'longitude': -73.98582},
#    'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '34 W 35th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['34 W 35th St', 'New York, NY 10001']},
#    'phone': '+12125644430',
#    'display_phone': '(212) 564-4430',
#    'distance': 4968.473297353009},
#   {'id': 'fVbUVAiLiGgLA_nxBFxyww',
#    'alias': 'thursday-kitchen-new-york',
#    'name': 'Thursday Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5P_HFhM6w8cRK3IiCzrNTQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thursday-kitchen-new-york?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#    'review_count': 1161,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7275, 'longitude': -73.9838},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '424 E 9th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['424 E 9th St', 'New York, NY 10009']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2613.42601480514},
#   {'id': 'ULt3kmA0_hbZ3j6cMORCaA',
#    'alias': 'root-and-bone-new-york',
#    'name': 'Root & Bone',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2WM96Qsx-7o11LNp1Lin9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/root-and-bone-new-york?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#    'review_count': 1480,
#    'categories': [{'alias': 'southern', 'title': 'Southern'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72272, 'longitude': -73.98334},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '200 E 3rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['200 E 3rd St', 'New York, NY 10009']},
#    'phone': '+16466827080',
#    'display_phone': '(646) 682-7080',
#    'distance': 2129.537859707603}],
#  'total': 18800,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#extracting the values(elements) in the 'businesses' key from data5 dict.
data5 = data5['businesses']
data5
# Out:
# [{'id': 'lMy1BYJ5HX8TccXTBwdRNg',
#   'alias': 'covenhoven-brooklyn',
#   'name': 'Covenhoven',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OZZ2U4MyoiBUrjQMZgqcRg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/covenhoven-brooklyn?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#   'review_count': 113,
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'salad', 'title': 'Salad'},
#    {'alias': 'soup', 'title': 'Soup'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.675246, 'longitude': -73.960244},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '730 Classon Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11238',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['730 Classon Ave', 'Brooklyn, NY 11238']},
#   'phone': '+17184839950',
#   'display_phone': '(718) 483-9950',
#   'distance': 4417.8365326838175},
#  {'id': 'ETgJqJHV7BW6pIr9Ox74sA',
#   'alias': 'amélie-new-york',
#   'name': 'Amélie',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cSDgVuPMnJgMLTrTNSEXug/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/am%C3%A9lie-new-york?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#   'review_count': 2450,
#   'categories': [{'alias': 'french', 'title': 'French'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7327, 'longitude': -73.99766},
#   'transactions': ['restaurant_reservation'],
#   'price': '$$',
#   'location': {'address1': '22 W 8th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10011',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['22 W 8th St', 'New York, NY 10011']},
#   'phone': '+12125332962',
#   'display_phone': '(212) 533-2962',
#   'distance': 3038.8699032940094},
#  {'id': 'ehUuSk5gPTCQmwS_ubgKRA',
#   'alias': 'upstate-new-york-2',
#   'name': 'Upstate',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RvnUVU7MF7DT0RzNL-EebQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/upstate-new-york-2?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#   'review_count': 1705,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'},
#    {'alias': 'beerbar', 'title': 'Beer Bar'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7263139141197,
#    'longitude': -73.9864901976935},
#   'transactions': ['restaurant_reservation'],
#   'price': '$$',
#   'location': {'address1': '95 1st Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['95 1st Ave', 'New York, NY 10003']},
#   'phone': '+16467915400',
#   'display_phone': '(646) 791-5400',
#   'distance': 2411.9187177986864},
#  {'id': 'CwOAKJdX8AMz5iAoA-ZEuA',
#   'alias': 'uglyduckling-brooklyn',
#   'name': 'Uglyduckling',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zo96XEmO2i-KtBs0_5pQyA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/uglyduckling-brooklyn?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#   'review_count': 437,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.686023, 'longitude': -73.991302},
#   'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '166 Smith St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['166 Smith St', 'Brooklyn, NY 11201']},
#   'phone': '+17184513825',
#   'display_phone': '(718) 451-3825',
#   'distance': 2174.2838817065267},
#  {'id': 'jjJc_CrkB2HodEinB6cWww',
#   'alias': 'lovemama-new-york',
#   'name': 'LoveMama',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bLlFKTlVuLfmF-lIDGIjZA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lovemama-new-york?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#   'review_count': 4178,
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'malaysian', 'title': 'Malaysian'},
#    {'alias': 'vietnamese', 'title': 'Vietnamese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7303859, 'longitude': -73.9860613},
#   'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '174 2nd Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['174 2nd Ave', 'New York, NY 10003']},
#   'phone': '+12122545370',
#   'display_phone': '(212) 254-5370',
#   'distance': 2858.7729410008346},
#  {'id': 'I2lgw_7DUnwD92ND4PN-Ow',
#   'alias': 'aunt-jakes-new-york',
#   'name': "Aunt Jake's",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hMhn_lnES3QWc4Gtihvr0A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/aunt-jakes-new-york?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#   'review_count': 1163,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'},
#    {'alias': 'pastashops', 'title': 'Pasta Shops'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7190315, 'longitude': -73.9977161},
#   'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '149 Mulberry St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['149 Mulberry St', 'New York, NY 10013']},
#   'phone': '+16468580470',
#   'display_phone': '(646) 858-0470',
#   'distance': 1538.0627375870665},
#  {'id': 'UA2M9QFZghe-9th2KwLoWQ',
#   'alias': 'burger-and-lobster-new-york-4',
#   'name': 'Burger & Lobster',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1rHd7F4zztAsScwzM0vDmw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/burger-and-lobster-new-york-4?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#   'review_count': 5053,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.74007, 'longitude': -73.99344},
#   'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '39 W 19th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10011',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['39 W 19th St', 'New York, NY 10011']},
#   'phone': '+16468337532',
#   'display_phone': '(646) 833-7532',
#   'distance': 3852.2188529432046},
#  {'id': 'C2o3Iw-DXjoUJFgQIbiqkQ',
#   'alias': 'bocaphê-new-york-3',
#   'name': 'BoCaphe',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ck7z-CGvku5kJDPyRkIfew/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bocaph%C3%AA-new-york-3?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#   'review_count': 1113,
#   'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'french', 'title': 'French'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.722046, 'longitude': -73.997557},
#   'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '222 Lafayette St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['222 Lafayette St', 'New York, NY 10012']},
#   'phone': '+16468821939',
#   'display_phone': '(646) 882-1939',
#   'distance': 1866.3436634084576},
#  {'id': 's3jou_L_LVYGkNHiuhjlew',
#   'alias': 'boucherie-west-village-new-york-3',
#   'name': 'Boucherie West Village',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-5TXMVrjARsqKQHDg-hKbQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/boucherie-west-village-new-york-3?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#   'review_count': 1020,
#   'categories': [{'alias': 'french', 'title': 'French'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.733063, 'longitude': -74.0028772},
#   'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#   'price': '$$$',
#   'location': {'address1': '99 7th Ave S',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['99 7th Ave S', 'New York, NY 10014']},
#   'phone': '+12128371616',
#   'display_phone': '(212) 837-1616',
#   'distance': 3155.0505772747442},
#  {'id': 'hmdm-dO72hLsMQwQRcGEUQ',
#   'alias': 'atrium-dumbo-brooklyn',
#   'name': 'Atrium Dumbo',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TAog5s7slOJ0778OGRzuWQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/atrium-dumbo-brooklyn?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#   'review_count': 597,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'french', 'title': 'French'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7033899, 'longitude': -73.9904923},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '15 Main St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['15 Main St', 'Brooklyn, NY 11201']},
#   'phone': '+17188581095',
#   'display_phone': '(718) 858-1095',
#   'distance': 392.6441573431464},
#  {'id': 'xt4sa64WOrpJvZBDPNPNYg',
#   'alias': 'jacobs-pickles-new-york',
#   'name': "Jacob's Pickles",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/167Rl2s1oMge_2ZSDD1z0A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/jacobs-pickles-new-york?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#   'review_count': 3674,
#   'categories': [{'alias': 'comfortfood', 'title': 'Comfort Food'},
#    {'alias': 'southern', 'title': 'Southern'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7866504411994,
#    'longitude': -73.9755284786224},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '509 Amsterdam Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10024',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['509 Amsterdam Ave', 'New York, NY 10024']},
#   'phone': '+12124705566',
#   'display_phone': '(212) 470-5566',
#   'distance': 9166.964737863183},
#  {'id': 'ysqgdbSrezXgVwER2kQWKA',
#   'alias': 'julianas-pizza-brooklyn-5',
#   'name': "Juliana's Pizza",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7JtwTxhWHf3YS70Ss_CfxA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/julianas-pizza-brooklyn-5?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#   'review_count': 1950,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7026153030093,
#    'longitude': -73.9934159993549},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '19 Old Fulton St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['19 Old Fulton St', 'Brooklyn, NY 11201']},
#   'phone': '+17185966700',
#   'display_phone': '(718) 596-6700',
#   'distance': 323.20506308227306},
#  {'id': 'Me4TxTbPPQZQopW1wOGx5g',
#   'alias': 'jacks-wife-freda-new-york',
#   'name': "Jack's Wife Freda",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TRJ5LNNH7UAybD4TlCCf2Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/jacks-wife-freda-new-york?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#   'review_count': 1738,
#   'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'},
#    {'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.72213, 'longitude': -73.99756},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '224 Lafayette St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['224 Lafayette St', 'New York, NY 10012']},
#   'phone': '+12125108550',
#   'display_phone': '(212) 510-8550',
#   'distance': 1874.7368920314377},
#  {'id': 'qCrM1gDsY7bc3Tk61VBIBQ',
#   'alias': 'savida-new-york',
#   'name': 'Savida',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/oOk9vD2imIqAdGTWgduJeQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/savida-new-york?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#   'review_count': 27,
#   'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'mideastern', 'title': 'Middle Eastern'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.71645, 'longitude': -74.00783},
#   'transactions': ['restaurant_reservation'],
#   'location': {'address1': '139 Duane St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['139 Duane St', 'New York, NY 10013']},
#   'phone': '+12122023175',
#   'display_phone': '(212) 202-3175',
#   'distance': 1671.1005153773624},
#  {'id': '4aF0F8w7yXX9o5_QFky_ig',
#   'alias': 'celestine-brooklyn',
#   'name': 'Celestine',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Qioy61vucqa3heDewB8btg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/celestine-brooklyn?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#   'review_count': 154,
#   'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.704676, 'longitude': -73.987975},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1 John St',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1 John St', 'Brooklyn, NY 11201']},
#   'phone': '+17185225356',
#   'display_phone': '(718) 522-5356',
#   'distance': 539.4069533813018},
#  {'id': '0CjK3esfpFcxIopebzjFxA',
#   'alias': 'joes-shanghai-new-york-2',
#   'name': "Joe's Shanghai",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ekUo5egd4dlE7zJyb4-Leg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/joes-shanghai-new-york-2?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#   'review_count': 5704,
#   'categories': [{'alias': 'shanghainese', 'title': 'Shanghainese'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7146691442891,
#    'longitude': -73.9977602206654},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '9 Pell St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['9 Pell St', 'New York, NY 10013']},
#   'phone': '+12122338888',
#   'display_phone': '(212) 233-8888',
#   'distance': 1066.5085498349097},
#  {'id': 'qOomR3AwClOGpV1HdqOTFg',
#   'alias': 'les-enfants-de-boheme-new-york',
#   'name': 'Les Enfants de Boheme',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/I1V4kucJO69x8L8UhDwiiA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/les-enfants-de-boheme-new-york?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#   'review_count': 198,
#   'categories': [{'alias': 'french', 'title': 'French'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7136187, 'longitude': -73.9888503},
#   'transactions': ['restaurant_reservation'],
#   'price': '$$',
#   'location': {'address1': '177 Henry St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['177 Henry St', 'New York, NY 10002']},
#   'phone': '+16464764843',
#   'display_phone': '(646) 476-4843',
#   'distance': 1026.2110364656392},
#  {'id': 'xZ96vaoL-cQjfotmUKtjJQ',
#   'alias': 'barn-joo-35-new-york',
#   'name': 'Barn Joo 35',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1R5CgYlK5qGUhKZOvZThKw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/barn-joo-35-new-york?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#   'review_count': 1415,
#   'categories': [{'alias': 'korean', 'title': 'Korean'},
#    {'alias': 'gastropubs', 'title': 'Gastropubs'},
#    {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.74964, 'longitude': -73.98582},
#   'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '34 W 35th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10001',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['34 W 35th St', 'New York, NY 10001']},
#   'phone': '+12125644430',
#   'display_phone': '(212) 564-4430',
#   'distance': 4968.473297353009},
#  {'id': 'fVbUVAiLiGgLA_nxBFxyww',
#   'alias': 'thursday-kitchen-new-york',
#   'name': 'Thursday Kitchen',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5P_HFhM6w8cRK3IiCzrNTQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/thursday-kitchen-new-york?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#   'review_count': 1161,
#   'categories': [{'alias': 'korean', 'title': 'Korean'},
#    {'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7275, 'longitude': -73.9838},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '424 E 9th St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['424 E 9th St', 'New York, NY 10009']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 2613.42601480514},
#  {'id': 'ULt3kmA0_hbZ3j6cMORCaA',
#   'alias': 'root-and-bone-new-york',
#   'name': 'Root & Bone',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2WM96Qsx-7o11LNp1Lin9A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/root-and-bone-new-york?adjust_creative=PdG5NYNj9KqEVMaMf45xhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=PdG5NYNj9KqEVMaMf45xhA',
#   'review_count': 1480,
#   'categories': [{'alias': 'southern', 'title': 'Southern'},
#    {'alias': 'comfortfood', 'title': 'Comfort Food'},
#    {'alias': 'desserts', 'title': 'Desserts'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.72272, 'longitude': -73.98334},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '200 E 3rd St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10009',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['200 E 3rd St', 'New York, NY 10009']},
#   'phone': '+16466827080',
#   'display_phone': '(646) 682-7080',
#   'distance': 2129.537859707603}]

# %%
#converting data5 into dataframe
data5_df = pd.DataFrame(data5)
data5_df.head()
# Out:
#                    alias                                         categories  \
# 0    covenhoven-brooklyn  [{'alias': 'bars', 'title': 'Bars'}, {'alias':...
# 1        amélie-new-york  [{'alias': 'french', 'title': 'French'}, {'ali...
# 2     upstate-new-york-2  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...
# 3  uglyduckling-brooklyn  [{'alias': 'tradamerican', 'title': 'American ...
# 4      lovemama-new-york  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...
#
#                                          coordinates   display_phone  \
# 0   {'latitude': 40.675246, 'longitude': -73.960244}  (718) 483-9950
# 1      {'latitude': 40.7327, 'longitude': -73.99766}  (212) 533-2962
# 2  {'latitude': 40.7263139141197, 'longitude': -7...  (646) 791-5400
# 3   {'latitude': 40.686023, 'longitude': -73.991302}  (718) 451-3825
# 4  {'latitude': 40.7303859, 'longitude': -73.9860...  (212) 254-5370
#
#       distance                      id  \
# 0  4417.836533  lMy1BYJ5HX8TccXTBwdRNg
# 1  3038.869903  ETgJqJHV7BW6pIr9Ox74sA
# 2  2411.918718  ehUuSk5gPTCQmwS_ubgKRA
# 3  2174.283882  CwOAKJdX8AMz5iAoA-ZEuA
# 4  2858.772941  jjJc_CrkB2HodEinB6cWww
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/OZZ2U4...      False
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/cSDgVu...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/RvnUVU...      False
# 3  https://s3-media2.fl.yelpcdn.com/bphoto/zo96XE...      False
# 4  https://s3-media1.fl.yelpcdn.com/bphoto/bLlFKT...      False
#
#                                             location          name  \
# 0  {'address1': '730 Classon Ave', 'address2': No...    Covenhoven
# 1  {'address1': '22 W 8th St', 'address2': '', 'a...        Amélie
# 2  {'address1': '95 1st Ave', 'address2': '', 'ad...       Upstate
# 3  {'address1': '166 Smith St', 'address2': '', '...  Uglyduckling
# 4  {'address1': '174 2nd Ave', 'address2': '', 'a...      LoveMama
#
#           phone price  rating  review_count  \
# 0  +17184839950    $$     4.5           113
# 1  +12125332962    $$     4.5          2450
# 2  +16467915400    $$     4.5          1705
# 3  +17184513825    $$     4.0           437
# 4  +12122545370    $$     4.0          4178
#
#                                  transactions  \
# 0                                          []
# 1                    [restaurant_reservation]
# 2                    [restaurant_reservation]
# 3  [delivery, restaurant_reservation, pickup]
# 4  [delivery, restaurant_reservation, pickup]
#
#                                                  url
# 0  https://www.yelp.com/biz/covenhoven-brooklyn?a...
# 1  https://www.yelp.com/biz/am%C3%A9lie-new-york?...
# 2  https://www.yelp.com/biz/upstate-new-york-2?ad...
# 3  https://www.yelp.com/biz/uglyduckling-brooklyn...
# 4  https://www.yelp.com/biz/lovemama-new-york?adj...

# %% [markdown]
# Above data5_df shows the best restaurants in New York recommended by Yelp.com(https://www.yelp.com/search?cflt=restaurants&find_loc=New+York%2C+NY). I will check above five restaurants' inspectino results as below.

# %%
#creating a dataframe with a subset of columns in data5_df
yelp_best = data5_df[['name','phone','rating', 'review_count']]
yelp_best.head(10)
# Out:
#                      name         phone  rating  review_count
# 0              Covenhoven  +17184839950     4.5           113
# 1                  Amélie  +12125332962     4.5          2450
# 2                 Upstate  +16467915400     4.5          1705
# 3            Uglyduckling  +17184513825     4.0           437
# 4                LoveMama  +12122545370     4.0          4178
# 5             Aunt Jake's  +16468580470     4.0          1163
# 6        Burger & Lobster  +16468337532     4.0          5053
# 7                 BoCaphe  +16468821939     4.0          1113
# 8  Boucherie West Village  +12128371616     4.5          1020
# 9            Atrium Dumbo  +17188581095     4.0           597

# %% [markdown]
# Above table shows the best 10 restaurants in New York suggested by Yelp.com.

# %%
#extracting the data which contain the top 10 Yelp's recommended restaurants in df1, using phone number
inspect_df = df1[df1['PHONE'].isin(['7184839950', '2125332962', '6467915400', '6468580470', '6468337532', '7184513825', 
                                    '2122545370', '2127305848', '2128371616', '2125644430'])]
inspect_df
# Out:
#                 RESTAURANT    BOROUGH BUILDING            STREET       PHONE  \
# 262              BOUCHERIE  MANHATTAN       99         7TH AVE S  2128371616
# 263              BOUCHERIE  MANHATTAN       99         7TH AVE S  2128371616
# 264              BOUCHERIE  MANHATTAN       99         7TH AVE S  2128371616
# 265              BOUCHERIE  MANHATTAN       99         7TH AVE S  2128371616
# 19346          BARN JOO 35  MANHATTAN       34         W 35TH ST  2125644430
# 19347          BARN JOO 35  MANHATTAN       34         W 35TH ST  2125644430
# 19348          BARN JOO 35  MANHATTAN       34         W 35TH ST  2125644430
# 21168    THE UGLY DUCKLING   BROOKLYN      166          SMITH ST  7184513825
# 21169    THE UGLY DUCKLING   BROOKLYN      166          SMITH ST  7184513825
# 21170    THE UGLY DUCKLING   BROOKLYN      166          SMITH ST  7184513825
# 22124   IPANEMA RESTAURANT  MANHATTAN       43         W 46TH ST  2127305848
# 22125   IPANEMA RESTAURANT  MANHATTAN       43         W 46TH ST  2127305848
# 33007          BARN JOO 35  MANHATTAN       34         W 35TH ST  2125644430
# 33008          BARN JOO 35  MANHATTAN       34         W 35TH ST  2125644430
# 59744            BOUCHERIE  MANHATTAN       99         7TH AVE S  2128371616
# 59745            BOUCHERIE  MANHATTAN       99         7TH AVE S  2128371616
# 59746            BOUCHERIE  MANHATTAN       99         7TH AVE S  2128371616
# 59747            BOUCHERIE  MANHATTAN       99         7TH AVE S  2128371616
# 62213            BOUCHERIE  MANHATTAN       99         7TH AVE S  2128371616
# 62214            BOUCHERIE  MANHATTAN       99         7TH AVE S  2128371616
# 76945               AMELIE  MANHATTAN       22  WEST    8 STREET  2125332962
# 76946               AMELIE  MANHATTAN       22  WEST    8 STREET  2125332962
# 76947               AMELIE  MANHATTAN       22  WEST    8 STREET  2125332962
# 85546          BARN JOO 35  MANHATTAN       34         W 35TH ST  2125644430
# 92092     BURGER & LOBSTER  MANHATTAN       39         W 19TH ST  6468337532
# 92093     BURGER & LOBSTER  MANHATTAN       39         W 19TH ST  6468337532
# 92094     BURGER & LOBSTER  MANHATTAN       39         W 19TH ST  6468337532
# 92095     BURGER & LOBSTER  MANHATTAN       39         W 19TH ST  6468337532
# 92096     BURGER & LOBSTER  MANHATTAN       39         W 19TH ST  6468337532
# 92097     BURGER & LOBSTER  MANHATTAN       39         W 19TH ST  6468337532
# ...                    ...        ...      ...               ...         ...
# 222974              AMELIE  MANHATTAN       22  WEST    8 STREET  2125332962
# 225776  IPANEMA RESTAURANT  MANHATTAN       43         W 46TH ST  2127305848
# 225777  IPANEMA RESTAURANT  MANHATTAN       43         W 46TH ST  2127305848
# 244901         BARN JOO 35  MANHATTAN       34         W 35TH ST  2125644430
# 244902         BARN JOO 35  MANHATTAN       34         W 35TH ST  2125644430
# 244903         BARN JOO 35  MANHATTAN       34         W 35TH ST  2125644430
# 244904         BARN JOO 35  MANHATTAN       34         W 35TH ST  2125644430
# 248350   THE UGLY DUCKLING   BROOKLYN      166          SMITH ST  7184513825
# 248351   THE UGLY DUCKLING   BROOKLYN      166          SMITH ST  7184513825
# 248352   THE UGLY DUCKLING   BROOKLYN      166          SMITH ST  7184513825
# 248353   THE UGLY DUCKLING   BROOKLYN      166          SMITH ST  7184513825
# 248354   THE UGLY DUCKLING   BROOKLYN      166          SMITH ST  7184513825
# 248355   THE UGLY DUCKLING   BROOKLYN      166          SMITH ST  7184513825
# 251262         AUNT JAKE-S  MANHATTAN      149       MULBERRY ST  6468580470
# 251263         AUNT JAKE-S  MANHATTAN      149       MULBERRY ST  6468580470
# 251264         AUNT JAKE-S  MANHATTAN      149       MULBERRY ST  6468580470
# 251265         AUNT JAKE-S  MANHATTAN      149       MULBERRY ST  6468580470
# 251266         AUNT JAKE-S  MANHATTAN      149       MULBERRY ST  6468580470
# 251267         AUNT JAKE-S  MANHATTAN      149       MULBERRY ST  6468580470
# 251268         AUNT JAKE-S  MANHATTAN      149       MULBERRY ST  6468580470
# 259220         BARN JOO 35  MANHATTAN       34         W 35TH ST  2125644430
# 259221         BARN JOO 35  MANHATTAN       34         W 35TH ST  2125644430
# 259222         BARN JOO 35  MANHATTAN       34         W 35TH ST  2125644430
# 259223         BARN JOO 35  MANHATTAN       34         W 35TH ST  2125644430
# 259224         BARN JOO 35  MANHATTAN       34         W 35TH ST  2125644430
# 260690         AUNT JAKE-S  MANHATTAN      149       MULBERRY ST  6468580470
# 260691         AUNT JAKE-S  MANHATTAN      149       MULBERRY ST  6468580470
# 260692         AUNT JAKE-S  MANHATTAN      149       MULBERRY ST  6468580470
# 260693         AUNT JAKE-S  MANHATTAN      149       MULBERRY ST  6468580470
# 261304         BARN JOO 35  MANHATTAN       34         W 35TH ST  2125644430
#
#        CUISINE DESCRIPTION INSPECTION DATE  \
# 262                 French      2017-05-01
# 263                 French      2017-05-01
# 264                 French      2017-05-01
# 265                 French      2017-05-01
# 19346               Korean      2017-07-19
# 19347               Korean      2017-07-19
# 19348               Korean      2017-07-19
# 21168             American      2017-07-25
# 21169             American      2017-07-25
# 21170             American      2017-07-25
# 22124            Brazilian      2017-07-27
# 22125            Brazilian      2017-07-27
# 33007               Korean      2017-09-05
# 33008               Korean      2017-09-05
# 59744               French      2017-12-11
# 59745               French      2017-12-11
# 59746               French      2017-12-11
# 59747               French      2017-12-11
# 62213               French      2017-12-19
# 62214               French      2017-12-19
# 76945               French      2018-02-01
# 76946               French      2018-02-01
# 76947               French      2018-02-01
# 85546               Korean      2018-02-22
# 92092             American      2018-03-12
# 92093             American      2018-03-12
# 92094             American      2018-03-12
# 92095             American      2018-03-12
# 92096             American      2018-03-12
# 92097             American      2018-03-12
# ...                    ...             ...
# 222974              French      2019-02-13
# 225776           Brazilian      2019-02-20
# 225777           Brazilian      2019-02-20
# 244901              Korean      2019-03-28
# 244902              Korean      2019-03-28
# 244903              Korean      2019-03-28
# 244904              Korean      2019-03-28
# 248350            American      2019-04-03
# 248351            American      2019-04-03
# 248352            American      2019-04-03
# 248353            American      2019-04-03
# 248354            American      2019-04-03
# 248355            American      2019-04-03
# 251262             Italian      2019-04-09
# 251263             Italian      2019-04-09
# 251264             Italian      2019-04-09
# 251265             Italian      2019-04-09
# 251266             Italian      2019-04-09
# 251267             Italian      2019-04-09
# 251268             Italian      2019-04-09
# 259220              Korean      2019-04-24
# 259221              Korean      2019-04-24
# 259222              Korean      2019-04-24
# 259223              Korean      2019-04-24
# 259224              Korean      2019-04-24
# 260690             Italian      2019-04-26
# 260691             Italian      2019-04-26
# 260692             Italian      2019-04-26
# 260693             Italian      2019-04-26
# 261304              Korean      2019-04-29
#
#                                                    ACTION  \
# 262       Violations were cited in the following area(s).
# 263       Violations were cited in the following area(s).
# 264       Violations were cited in the following area(s).
# 265       Violations were cited in the following area(s).
# 19346     Violations were cited in the following area(s).
# 19347     Violations were cited in the following area(s).
# 19348     Violations were cited in the following area(s).
# 21168     Violations were cited in the following area(s).
# 21169     Violations were cited in the following area(s).
# 21170     Violations were cited in the following area(s).
# 22124     Violations were cited in the following area(s).
# 22125     Violations were cited in the following area(s).
# 33007     Violations were cited in the following area(s).
# 33008     Violations were cited in the following area(s).
# 59744     Violations were cited in the following area(s).
# 59745     Violations were cited in the following area(s).
# 59746     Violations were cited in the following area(s).
# 59747     Violations were cited in the following area(s).
# 62213     Violations were cited in the following area(s).
# 62214     Violations were cited in the following area(s).
# 76945     Violations were cited in the following area(s).
# 76946     Violations were cited in the following area(s).
# 76947     Violations were cited in the following area(s).
# 85546     Violations were cited in the following area(s).
# 92092     Violations were cited in the following area(s).
# 92093     Violations were cited in the following area(s).
# 92094     Violations were cited in the following area(s).
# 92095     Violations were cited in the following area(s).
# 92096     Violations were cited in the following area(s).
# 92097     Violations were cited in the following area(s).
# ...                                                   ...
# 222974    Violations were cited in the following area(s).
# 225776    Violations were cited in the following area(s).
# 225777    Violations were cited in the following area(s).
# 244901    Violations were cited in the following area(s).
# 244902    Violations were cited in the following area(s).
# 244903    Violations were cited in the following area(s).
# 244904    Violations were cited in the following area(s).
# 248350    Violations were cited in the following area(s).
# 248351    Violations were cited in the following area(s).
# 248352    Violations were cited in the following area(s).
# 248353    Violations were cited in the following area(s).
# 248354    Violations were cited in the following area(s).
# 248355    Violations were cited in the following area(s).
# 251262    Violations were cited in the following area(s).
# 251263    Violations were cited in the following area(s).
# 251264    Violations were cited in the following area(s).
# 251265    Violations were cited in the following area(s).
# 251266    Violations were cited in the following area(s).
# 251267    Violations were cited in the following area(s).
# 251268    Violations were cited in the following area(s).
# 259220  Establishment Closed by DOHMH.  Violations wer...
# 259221  Establishment Closed by DOHMH.  Violations wer...
# 259222  Establishment Closed by DOHMH.  Violations wer...
# 259223  Establishment Closed by DOHMH.  Violations wer...
# 259224  Establishment Closed by DOHMH.  Violations wer...
# 260690    Violations were cited in the following area(s).
# 260691    Violations were cited in the following area(s).
# 260692    Violations were cited in the following area(s).
# 260693    Violations were cited in the following area(s).
# 261304                   Establishment re-opened by DOHMH
#
#                                     VIOLATION DESCRIPTION  SCORE GRADE
# 262     Evidence of mice or live mice present in facil...     15     B
# 263     Food contact surface not properly washed, rins...     15     B
# 264     Non-food contact surface improperly constructe...     15     B
# 265     Proper sanitization not provided for utensil w...     15     B
# 19346   Raw, cooked or prepared food is adulterated, c...     17   NaN
# 19347   Sanitized equipment or utensil, including in-u...     17   NaN
# 19348   Wiping cloths soiled or not stored in sanitizi...     17   NaN
# 21168   Food not protected from potential source of co...     12     A
# 21169   Food contact surface not properly washed, rins...     12     A
# 21170   Non-food contact surface improperly constructe...     12     A
# 22124   Food worker does not use proper utensil to eli...      9     A
# 22125   Non-food contact surface improperly constructe...      9     A
# 33007         Hot food item not held at or above 140Âº F.     13     A
# 33008   Food contact surface not properly washed, rins...     13     A
# 59744   Cold food item held above 41Âº F (smoked fish ...     20   NaN
# 59745   Evidence of mice or live mice present in facil...     20   NaN
# 59746   Facility not vermin proof. Harborage or condit...     20   NaN
# 59747               Current letter grade card not posted.      0   NaN
# 62213   Evidence of mice or live mice present in facil...      6     A
# 62214               Current letter grade card not posted.      0   NaN
# 76945   Food contact surface not properly washed, rins...     12     A
# 76946       Food contact surface not properly maintained.     12     A
# 76947   Non-food contact surface improperly constructe...     12     A
# 85546                                                 NaN      0   NaN
# 92092         Hot food item not held at or above 140Âº F.     35   NaN
# 92093   Filth flies or food/refuse/sewage-associated (...     35   NaN
# 92094   Tobacco use, eating, or drinking from open con...     35   NaN
# 92095   Food contact surface not properly washed, rins...     35   NaN
# 92096   Facility not vermin proof. Harborage or condit...     35   NaN
# 92097   Plumbing not properly installed or maintained;...     35   NaN
# ...                                                   ...    ...   ...
# 222974  Non-food contact surface improperly constructe...      6     A
# 225776  Wiping cloths soiled or not stored in sanitizi...      8     A
# 225777  Plumbing not properly installed or maintained;...      8     A
# 244901  Appropriately scaled metal stem-type thermomet...     23   NaN
# 244902  Evidence of mice or live mice present in facil...     23   NaN
# 244903  Wiping cloths soiled or not stored in sanitizi...     23   NaN
# 244904  Facility not vermin proof. Harborage or condit...     23   NaN
# 248350  Raw, cooked or prepared food is adulterated, c...     26   NaN
# 248351  Food not protected from potential source of co...     26   NaN
# 248352  Food contact surface not properly washed, rins...     26   NaN
# 248353  Wiping cloths soiled or not stored in sanitizi...     26   NaN
# 248354      Food contact surface not properly maintained.     26   NaN
# 248355  Lighting inadequate; permanent lighting not pr...     26   NaN
# 251262  Cold food item held above 41Âº F (smoked fish ...     33   NaN
# 251263  Food worker does not use proper utensil to eli...     33   NaN
# 251264  Personal cleanliness inadequate. Outer garment...     33   NaN
# 251265  Food contact surface not properly washed, rins...     33   NaN
# 251266  Non-food contact surface improperly constructe...     33   NaN
# 251267  Proper sanitization not provided for utensil w...     33   NaN
# 251268  Single service item reused, improperly stored,...     33   NaN
# 259220  Raw, cooked or prepared food is adulterated, c...     47   NaN
# 259221  Evidence of mice or live mice present in facil...     47   NaN
# 259222  Food not protected from potential source of co...     47   NaN
# 259223  Facility not vermin proof. Harborage or condit...     47   NaN
# 259224  Non-food contact surface improperly constructe...     47   NaN
# 260690  Cold food item held above 41Âº F (smoked fish ...     27     Z
# 260691  Appropriately scaled metal stem-type thermomet...     27     Z
# 260692  Tobacco use, eating, or drinking from open con...     27     Z
# 260693  Food not protected from potential source of co...     27     Z
# 261304  Plumbing not properly installed or maintained;...      2     Z
#
# [106 rows x 11 columns]

# %%
#extracting the year from 'INSPECTINO DATE' column
inspect_df['INSPECTION DATE'] = inspect_df['INSPECTION DATE'].map(lambda x: x.year)
# Out:
# C:\Users\Minyeong\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#grouping by 'RESTAURANT','STREET',GRADE','INSPECTION DATE' and then calculating the mean of 'SCORE' column.
grouped_inspect_df = inspect_df.groupby(['RESTAURANT','STREET', 'GRADE', 'INSPECTION DATE'])['SCORE'].agg([('Average Score', 'mean')]).sort_values(by=['RESTAURANT'], ascending=False)
grouped_inspect_df
# Out:
#                                                            Average Score
# RESTAURANT         STREET           GRADE INSPECTION DATE
# THE UGLY DUCKLING  SMITH ST         A     2018                        12
#                                           2017                        12
# IPANEMA RESTAURANT W 46TH ST        A     2019                         8
#                                           2018                        10
#                                           2017                         9
# BURGER & LOBSTER   W 19TH ST        A     2019                         9
#                                           2018                        12
# BOUCHERIE          7TH AVE S        B     2017                        15
#                                     A     2018                        10
#                                           2017                         6
# BARN JOO 35        W 35TH ST        Z     2019                         2
#                                     A     2018                         7
#                                           2017                        13
# AUNT JAKE-S        MULBERRY ST      Z     2019                        27
#                                     A     2018                         5
# AMELIE             WEST    8 STREET A     2019                         6
#                                           2018                        12

# %% [markdown]
# Except the three restaurants that do not have matched phone number in the inspection result dataset df1, we can see the GRADE for each of the Yelp's best restaurants. Among the seven restaurants in the table, only three restaurants received A GRADE in 2019, two were not inspected in 2019, and two restaurants received pending grade in 2019. This result also confirms that Yelp's best restaurants are not necessarily compliant with the City and State food safety regulations.

# %% [markdown]
# ### Phase 9: Conclusions

# %% [markdown]
# In conclusion, restaurants that we see as the best restaurants on Yelp.com do not necessarily have the best inspection results. Yelp's star ratings and revews are frequently used to decide where to eat ouside home in our everyday life, however, by doing this project, I learned that the Yelp's star ratings and reviews do not guarantee the respective restaurant's compliance with the City and State food safety regulations. Hence, I would suggest that we should refer to the Health Department's restaurant inspection result once we pick a restaurant based on the Yelp. Although Yelp is a good starting point to search for the restaurant quickly, I think the end-point should be the Helath Department's restaurant inspection result to ensure that we are having food that is safe to eat, and prepared in safe environments.
